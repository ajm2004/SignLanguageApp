# %%
import cv2
from cvzone.HandTrackingModule import HandDetector
import numpy as np
import math
import time
import os

# Initialize webcam
cap = cv2.VideoCapture(0)

# Initialize hand detector
detector = HandDetector(maxHands=1)

# Constants
offset = 20
imgSize = 900
baseFolder = "C:/Users/User/OneDrive/Documents/SignLanguageApp/SLangDataset/data"
letters = [chr(i) for i in range(ord('A'), ord('Z') + 1)]  # List of letters A-Z
captureInterval = 0.001  # Interval between captures in seconds

# Loop through each letter
for className in letters:
    print(f"Starting collection for class: {className}")
    folder = os.path.join(baseFolder, className)
    os.makedirs(folder, exist_ok=True)

    # Initialize counter for the current class
    counter = 0
    maxImages = 2000

    collecting = False

    while counter < maxImages:
        success, img = cap.read()
        if not success:
            print("Failed to access camera.")
            break

        # Detect hands in the image
        hands, img = detector.findHands(img)
        if hands:
            hand = hands[0]
            x, y, w, h = hand['bbox']

            # Create a white canvas
            imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 255

            # Crop the image around the detected hand
            imgCrop = img[y - offset:y + h + offset, x - offset:x + w + offset]

            # Prevent errors from invalid crop boundaries
            if imgCrop.size == 0:
                continue

            aspectRatio = h / w

            try:
                if aspectRatio > 1:
                    # Height is greater than width
                    k = imgSize / h
                    wCal = math.ceil(k * w)
                    imgResize = cv2.resize(imgCrop, (wCal, imgSize))
                    wGap = math.ceil((imgSize - wCal) / 2)
                    imgWhite[:, wGap:wCal + wGap] = imgResize
                else:
                    # Width is greater than height
                    k = imgSize / w
                    hCal = math.ceil(k * h)
                    imgResize = cv2.resize(imgCrop, (imgSize, hCal))
                    hGap = math.ceil((imgSize - hCal) / 2)
                    imgWhite[hGap:hCal + hGap, :] = imgResize

                # Display the processed images
                cv2.imshow("ImageCrop", imgCrop)
                cv2.imshow("ImageWhite", imgWhite)
            except Exception as e:
                print(f"Error processing image: {e}")
                continue

            if collecting:
                # Save the image automatically
                counter += 1
                filePath = os.path.join(folder, f"{className.lower()}_{counter}.jpg")
                cv2.imwrite(filePath, imgWhite)
                print(f"Saved {counter}/{maxImages} images for class {className}")

        # Display the original image
        cv2.imshow("Image", img)

        # Check for key press
        key = cv2.waitKey(1)
        if key == ord('q'):
            collecting = True

        # Wait for the interval
        time.sleep(captureInterval)

    print(f"Completed collection for {className}.")
    input("Press 'Enter' to continue to the next letter.")

# Release the webcam and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Starting collection for class: B
# Saved 1/2000 images for class B
# Saved 2/2000 images for class B
# Saved 3/2000 images for class B
# Saved 4/2000 images for class B
# Saved 5/2000 images for class B
# Saved 6/2000 images for class B
# Saved 7/2000 images for class B
# Saved 8/2000 images for class B
# Saved 9/2000 images for class B
# Saved 10/2000 images for class B
# Saved 11/2000 images for class B
# Saved 12/2000 images for class B
# Saved 13/2000 images for class B
# Saved 14/2000 images for class B
# Saved 15/2000 images for class B
# Saved 16/2000 images for class B
# Saved 17/2000 images for class B
# Saved 18/2000 images for class B
# Saved 19/2000 images for class B
# Saved 20/2000 images for class B
# Saved 21/2000 images for class B
# Saved 22/2000 images for class B
# Saved 23/2000 images for class B
# Saved 24/2000 images for class B
# Saved 25/2000 images for class B
# Saved 26/2000 images for class B
# Saved 27/2000 images for class B
# Saved 28/2000 images for class B
# Saved 29/2000 images for class B
# Saved 30/2000 images for class B
# Saved 31/2000 images for class B
# Saved 32/2000 images for class B
# Saved 33/2000 images for class B
# Saved 34/2000 images for class B
# Saved 35/2000 images for class B
# Saved 36/2000 images for class B
# Saved 37/2000 images for class B
# Saved 38/2000 images for class B
# Saved 39/2000 images for class B
# Saved 40/2000 images for class B
# Saved 41/2000 images for class B
# Saved 42/2000 images for class B
# Saved 43/2000 images for class B
# Saved 44/2000 images for class B
# Saved 45/2000 images for class B
# Saved 46/2000 images for class B
# Saved 47/2000 images for class B
# Saved 48/2000 images for class B
# Saved 49/2000 images for class B
# Saved 50/2000 images for class B
# Saved 51/2000 images for class B
# Saved 52/2000 images for class B
# Saved 53/2000 images for class B
# Saved 54/2000 images for class B
# Saved 55/2000 images for class B
# Saved 56/2000 images for class B
# Saved 57/2000 images for class B
# Saved 58/2000 images for class B
# Saved 59/2000 images for class B
# Saved 60/2000 images for class B
# Saved 61/2000 images for class B
# Saved 62/2000 images for class B
# Saved 63/2000 images for class B
# Saved 64/2000 images for class B
# Saved 65/2000 images for class B
# Saved 66/2000 images for class B
# Saved 67/2000 images for class B
# Saved 68/2000 images for class B
# Saved 69/2000 images for class B
# Saved 70/2000 images for class B
# Saved 71/2000 images for class B
# Saved 72/2000 images for class B
# Saved 73/2000 images for class B
# Saved 74/2000 images for class B
# Saved 75/2000 images for class B
# Saved 76/2000 images for class B
# Saved 77/2000 images for class B
# Saved 78/2000 images for class B
# Saved 79/2000 images for class B
# Saved 80/2000 images for class B
# Saved 81/2000 images for class B
# Saved 82/2000 images for class B
# Saved 83/2000 images for class B
# Saved 84/2000 images for class B
# Saved 85/2000 images for class B
# Saved 86/2000 images for class B
# Saved 87/2000 images for class B
# Saved 88/2000 images for class B
# Saved 89/2000 images for class B
# Saved 90/2000 images for class B
# Saved 91/2000 images for class B
# Saved 92/2000 images for class B
# Saved 93/2000 images for class B
# Saved 94/2000 images for class B
# Saved 95/2000 images for class B
# Saved 96/2000 images for class B
# Saved 97/2000 images for class B
# Saved 98/2000 images for class B
# Saved 99/2000 images for class B
# Saved 100/2000 images for class B
# Saved 101/2000 images for class B
# Saved 102/2000 images for class B
# Saved 103/2000 images for class B
# Saved 104/2000 images for class B
# Saved 105/2000 images for class B
# Saved 106/2000 images for class B
# Saved 107/2000 images for class B
# Saved 108/2000 images for class B
# Saved 109/2000 images for class B
# Saved 110/2000 images for class B
# Saved 111/2000 images for class B
# Saved 112/2000 images for class B
# Saved 113/2000 images for class B
# Saved 114/2000 images for class B
# Saved 115/2000 images for class B
# Saved 116/2000 images for class B
# Saved 117/2000 images for class B
# Saved 118/2000 images for class B
# Saved 119/2000 images for class B
# Saved 120/2000 images for class B
# Saved 121/2000 images for class B
# Saved 122/2000 images for class B
# Saved 123/2000 images for class B
# Saved 124/2000 images for class B
# Saved 125/2000 images for class B
# Saved 126/2000 images for class B
# Saved 127/2000 images for class B
# Saved 128/2000 images for class B
# Saved 129/2000 images for class B
# Saved 130/2000 images for class B
# Saved 131/2000 images for class B
# Saved 132/2000 images for class B
# Saved 133/2000 images for class B
# Saved 134/2000 images for class B
# Saved 135/2000 images for class B
# Saved 136/2000 images for class B
# Saved 137/2000 images for class B
# Saved 138/2000 images for class B
# Saved 139/2000 images for class B
# Saved 140/2000 images for class B
# Saved 141/2000 images for class B
# Saved 142/2000 images for class B
# Saved 143/2000 images for class B
# Saved 144/2000 images for class B
# Saved 145/2000 images for class B
# Saved 146/2000 images for class B
# Saved 147/2000 images for class B
# Saved 148/2000 images for class B
# Saved 149/2000 images for class B
# Saved 150/2000 images for class B
# Saved 151/2000 images for class B
# Saved 152/2000 images for class B
# Saved 153/2000 images for class B
# Saved 154/2000 images for class B
# Saved 155/2000 images for class B
# Saved 156/2000 images for class B
# Saved 157/2000 images for class B
# Saved 158/2000 images for class B
# Saved 159/2000 images for class B
# Saved 160/2000 images for class B
# Saved 161/2000 images for class B
# Saved 162/2000 images for class B
# Saved 163/2000 images for class B
# Saved 164/2000 images for class B
# Saved 165/2000 images for class B
# Saved 166/2000 images for class B
# Saved 167/2000 images for class B
# Saved 168/2000 images for class B
# Saved 169/2000 images for class B
# Saved 170/2000 images for class B
# Saved 171/2000 images for class B
# Saved 172/2000 images for class B
# Saved 173/2000 images for class B
# Saved 174/2000 images for class B
# Saved 175/2000 images for class B
# Saved 176/2000 images for class B
# Saved 177/2000 images for class B
# Saved 178/2000 images for class B
# Saved 179/2000 images for class B
# Saved 180/2000 images for class B
# Saved 181/2000 images for class B
# Saved 182/2000 images for class B
# Saved 183/2000 images for class B
# Saved 184/2000 images for class B
# Saved 185/2000 images for class B
# Saved 186/2000 images for class B
# Saved 187/2000 images for class B
# Saved 188/2000 images for class B
# Saved 189/2000 images for class B
# Saved 190/2000 images for class B
# Saved 191/2000 images for class B
# Saved 192/2000 images for class B
# Saved 193/2000 images for class B
# Saved 194/2000 images for class B
# Saved 195/2000 images for class B
# Saved 196/2000 images for class B
# Saved 197/2000 images for class B
# Saved 198/2000 images for class B
# Saved 199/2000 images for class B
# Saved 200/2000 images for class B
# Saved 201/2000 images for class B
# Saved 202/2000 images for class B
# Saved 203/2000 images for class B
# Saved 204/2000 images for class B
# Saved 205/2000 images for class B
# Saved 206/2000 images for class B
# Saved 207/2000 images for class B
# Saved 208/2000 images for class B
# Saved 209/2000 images for class B
# Saved 210/2000 images for class B
# Saved 211/2000 images for class B
# Saved 212/2000 images for class B
# Saved 213/2000 images for class B
# Saved 214/2000 images for class B
# Saved 215/2000 images for class B
# Saved 216/2000 images for class B
# Saved 217/2000 images for class B
# Saved 218/2000 images for class B
# Saved 219/2000 images for class B
# Saved 220/2000 images for class B
# Saved 221/2000 images for class B
# Saved 222/2000 images for class B
# Saved 223/2000 images for class B
# Saved 224/2000 images for class B
# Saved 225/2000 images for class B
# Saved 226/2000 images for class B
# Saved 227/2000 images for class B
# Saved 228/2000 images for class B
# Saved 229/2000 images for class B
# Saved 230/2000 images for class B
# Saved 231/2000 images for class B
# Saved 232/2000 images for class B
# Saved 233/2000 images for class B
# Saved 234/2000 images for class B
# Saved 235/2000 images for class B
# Saved 236/2000 images for class B
# Saved 237/2000 images for class B
# Saved 238/2000 images for class B
# Saved 239/2000 images for class B
# Saved 240/2000 images for class B
# Saved 241/2000 images for class B
# Saved 242/2000 images for class B
# Saved 243/2000 images for class B
# Saved 244/2000 images for class B
# Saved 245/2000 images for class B
# Saved 246/2000 images for class B
# Saved 247/2000 images for class B
# Saved 248/2000 images for class B
# Saved 249/2000 images for class B
# Saved 250/2000 images for class B
# Saved 251/2000 images for class B
# Saved 252/2000 images for class B
# Saved 253/2000 images for class B
# Saved 254/2000 images for class B
# Saved 255/2000 images for class B
# Saved 256/2000 images for class B
# Saved 257/2000 images for class B
# Saved 258/2000 images for class B
# Saved 259/2000 images for class B
# Saved 260/2000 images for class B
# Saved 261/2000 images for class B
# Saved 262/2000 images for class B
# Saved 263/2000 images for class B
# Saved 264/2000 images for class B
# Saved 265/2000 images for class B
# Saved 266/2000 images for class B
# Saved 267/2000 images for class B
# Saved 268/2000 images for class B
# Saved 269/2000 images for class B
# Saved 270/2000 images for class B
# Saved 271/2000 images for class B
# Saved 272/2000 images for class B
# Saved 273/2000 images for class B
# Saved 274/2000 images for class B
# Saved 275/2000 images for class B
# Saved 276/2000 images for class B
# Saved 277/2000 images for class B
# Saved 278/2000 images for class B
# Saved 279/2000 images for class B
# Saved 280/2000 images for class B
# Saved 281/2000 images for class B
# Saved 282/2000 images for class B
# Saved 283/2000 images for class B
# Saved 284/2000 images for class B
# Saved 285/2000 images for class B
# Saved 286/2000 images for class B
# Saved 287/2000 images for class B
# Saved 288/2000 images for class B
# Saved 289/2000 images for class B
# Saved 290/2000 images for class B
# Saved 291/2000 images for class B
# Saved 292/2000 images for class B
# Saved 293/2000 images for class B
# Saved 294/2000 images for class B
# Saved 295/2000 images for class B
# Saved 296/2000 images for class B
# Saved 297/2000 images for class B
# Saved 298/2000 images for class B
# Saved 299/2000 images for class B
# Saved 300/2000 images for class B
# Saved 301/2000 images for class B
# Saved 302/2000 images for class B
# Saved 303/2000 images for class B
# Saved 304/2000 images for class B
# Saved 305/2000 images for class B
# Saved 306/2000 images for class B
# Saved 307/2000 images for class B
# Saved 308/2000 images for class B
# Saved 309/2000 images for class B
# Saved 310/2000 images for class B
# Saved 311/2000 images for class B
# Saved 312/2000 images for class B
# Saved 313/2000 images for class B
# Saved 314/2000 images for class B
# Saved 315/2000 images for class B
# Saved 316/2000 images for class B
# Saved 317/2000 images for class B
# Saved 318/2000 images for class B
# Saved 319/2000 images for class B
# Saved 320/2000 images for class B
# Saved 321/2000 images for class B
# Saved 322/2000 images for class B
# Saved 323/2000 images for class B
# Saved 324/2000 images for class B
# Saved 325/2000 images for class B
# Saved 326/2000 images for class B
# Saved 327/2000 images for class B
# Saved 328/2000 images for class B
# Saved 329/2000 images for class B
# Saved 330/2000 images for class B
# Saved 331/2000 images for class B
# Saved 332/2000 images for class B
# Saved 333/2000 images for class B
# Saved 334/2000 images for class B
# Saved 335/2000 images for class B
# Saved 336/2000 images for class B
# Saved 337/2000 images for class B
# Saved 338/2000 images for class B
# Saved 339/2000 images for class B
# Saved 340/2000 images for class B
# Saved 341/2000 images for class B
# Saved 342/2000 images for class B
# Saved 343/2000 images for class B
# Saved 344/2000 images for class B
# Saved 345/2000 images for class B
# Saved 346/2000 images for class B
# Saved 347/2000 images for class B
# Saved 348/2000 images for class B
# Saved 349/2000 images for class B
# Saved 350/2000 images for class B
# Saved 351/2000 images for class B
# Saved 352/2000 images for class B
# Saved 353/2000 images for class B
# Saved 354/2000 images for class B
# Saved 355/2000 images for class B
# Saved 356/2000 images for class B
# Saved 357/2000 images for class B
# Saved 358/2000 images for class B
# Saved 359/2000 images for class B
# Saved 360/2000 images for class B
# Saved 361/2000 images for class B
# Saved 362/2000 images for class B
# Saved 363/2000 images for class B
# Saved 364/2000 images for class B
# Saved 365/2000 images for class B
# Saved 366/2000 images for class B
# Saved 367/2000 images for class B
# Saved 368/2000 images for class B
# Saved 369/2000 images for class B
# Saved 370/2000 images for class B
# Saved 371/2000 images for class B
# Saved 372/2000 images for class B
# Saved 373/2000 images for class B
# Saved 374/2000 images for class B
# Saved 375/2000 images for class B
# Saved 376/2000 images for class B
# Saved 377/2000 images for class B
# Saved 378/2000 images for class B
# Saved 379/2000 images for class B
# Saved 380/2000 images for class B
# Saved 381/2000 images for class B
# Saved 382/2000 images for class B
# Saved 383/2000 images for class B
# Saved 384/2000 images for class B
# Saved 385/2000 images for class B
# Saved 386/2000 images for class B
# Saved 387/2000 images for class B
# Saved 388/2000 images for class B
# Saved 389/2000 images for class B
# Saved 390/2000 images for class B
# Saved 391/2000 images for class B
# Saved 392/2000 images for class B
# Saved 393/2000 images for class B
# Saved 394/2000 images for class B
# Saved 395/2000 images for class B
# Saved 396/2000 images for class B
# Saved 397/2000 images for class B
# Saved 398/2000 images for class B
# Saved 399/2000 images for class B
# Saved 400/2000 images for class B
# Saved 401/2000 images for class B
# Saved 402/2000 images for class B
# Saved 403/2000 images for class B
# Saved 404/2000 images for class B
# Saved 405/2000 images for class B
# Saved 406/2000 images for class B
# Saved 407/2000 images for class B
# Saved 408/2000 images for class B
# Saved 409/2000 images for class B
# Saved 410/2000 images for class B
# Saved 411/2000 images for class B
# Saved 412/2000 images for class B
# Saved 413/2000 images for class B
# Saved 414/2000 images for class B
# Saved 415/2000 images for class B
# Saved 416/2000 images for class B
# Saved 417/2000 images for class B
# Saved 418/2000 images for class B
# Saved 419/2000 images for class B
# Saved 420/2000 images for class B
# Saved 421/2000 images for class B
# Saved 422/2000 images for class B
# Saved 423/2000 images for class B
# Saved 424/2000 images for class B
# Saved 425/2000 images for class B
# Saved 426/2000 images for class B
# Saved 427/2000 images for class B
# Saved 428/2000 images for class B
# Saved 429/2000 images for class B
# Saved 430/2000 images for class B
# Saved 431/2000 images for class B
# Saved 432/2000 images for class B
# Saved 433/2000 images for class B
# Saved 434/2000 images for class B
# Saved 435/2000 images for class B
# Saved 436/2000 images for class B
# Saved 437/2000 images for class B
# Saved 438/2000 images for class B
# Saved 439/2000 images for class B
# Saved 440/2000 images for class B
# Saved 441/2000 images for class B
# Saved 442/2000 images for class B
# Saved 443/2000 images for class B
# Saved 444/2000 images for class B
# Saved 445/2000 images for class B
# Saved 446/2000 images for class B
# Saved 447/2000 images for class B
# Saved 448/2000 images for class B
# Saved 449/2000 images for class B
# Saved 450/2000 images for class B
# Saved 451/2000 images for class B
# Saved 452/2000 images for class B
# Saved 453/2000 images for class B
# Saved 454/2000 images for class B
# Saved 455/2000 images for class B
# Saved 456/2000 images for class B
# Saved 457/2000 images for class B
# Saved 458/2000 images for class B
# Saved 459/2000 images for class B
# Saved 460/2000 images for class B
# Saved 461/2000 images for class B
# Saved 462/2000 images for class B
# Saved 463/2000 images for class B
# Saved 464/2000 images for class B
# Saved 465/2000 images for class B
# Saved 466/2000 images for class B
# Saved 467/2000 images for class B
# Saved 468/2000 images for class B
# Saved 469/2000 images for class B
# Saved 470/2000 images for class B
# Saved 471/2000 images for class B
# Saved 472/2000 images for class B
# Saved 473/2000 images for class B
# Saved 474/2000 images for class B
# Saved 475/2000 images for class B
# Saved 476/2000 images for class B
# Saved 477/2000 images for class B
# Saved 478/2000 images for class B
# Saved 479/2000 images for class B
# Saved 480/2000 images for class B
# Saved 481/2000 images for class B
# Saved 482/2000 images for class B
# Saved 483/2000 images for class B
# Saved 484/2000 images for class B
# Saved 485/2000 images for class B
# Saved 486/2000 images for class B
# Saved 487/2000 images for class B
# Saved 488/2000 images for class B
# Saved 489/2000 images for class B
# Saved 490/2000 images for class B
# Saved 491/2000 images for class B
# Saved 492/2000 images for class B
# Saved 493/2000 images for class B
# Saved 494/2000 images for class B
# Saved 495/2000 images for class B
# Saved 496/2000 images for class B
# Saved 497/2000 images for class B
# Saved 498/2000 images for class B
# Saved 499/2000 images for class B
# Saved 500/2000 images for class B
# Saved 501/2000 images for class B
# Saved 502/2000 images for class B
# Saved 503/2000 images for class B
# Saved 504/2000 images for class B
# Saved 505/2000 images for class B
# Saved 506/2000 images for class B
# Saved 507/2000 images for class B
# Saved 508/2000 images for class B
# Saved 509/2000 images for class B
# Saved 510/2000 images for class B
# Saved 511/2000 images for class B
# Saved 512/2000 images for class B
# Saved 513/2000 images for class B
# Saved 514/2000 images for class B
# Saved 515/2000 images for class B
# Saved 516/2000 images for class B
# Saved 517/2000 images for class B
# Saved 518/2000 images for class B
# Saved 519/2000 images for class B
# Saved 520/2000 images for class B
# Saved 521/2000 images for class B
# Saved 522/2000 images for class B
# Saved 523/2000 images for class B
# Saved 524/2000 images for class B
# Saved 525/2000 images for class B
# Saved 526/2000 images for class B
# Saved 527/2000 images for class B
# Saved 528/2000 images for class B
# Saved 529/2000 images for class B
# Saved 530/2000 images for class B
# Saved 531/2000 images for class B
# Saved 532/2000 images for class B
# Saved 533/2000 images for class B
# Saved 534/2000 images for class B
# Saved 535/2000 images for class B
# Saved 536/2000 images for class B
# Saved 537/2000 images for class B
# Saved 538/2000 images for class B
# Saved 539/2000 images for class B
# Saved 540/2000 images for class B
# Saved 541/2000 images for class B
# Saved 542/2000 images for class B
# Saved 543/2000 images for class B
# Saved 544/2000 images for class B
# Saved 545/2000 images for class B
# Saved 546/2000 images for class B
# Saved 547/2000 images for class B
# Saved 548/2000 images for class B
# Saved 549/2000 images for class B
# Saved 550/2000 images for class B
# Saved 551/2000 images for class B
# Saved 552/2000 images for class B
# Saved 553/2000 images for class B
# Saved 554/2000 images for class B
# Saved 555/2000 images for class B
# Saved 556/2000 images for class B
# Saved 557/2000 images for class B
# Saved 558/2000 images for class B
# Saved 559/2000 images for class B
# Saved 560/2000 images for class B
# Saved 561/2000 images for class B
# Saved 562/2000 images for class B
# Saved 563/2000 images for class B
# Saved 564/2000 images for class B
# Saved 565/2000 images for class B
# Saved 566/2000 images for class B
# Saved 567/2000 images for class B
# Saved 568/2000 images for class B
# Saved 569/2000 images for class B
# Saved 570/2000 images for class B
# Saved 571/2000 images for class B
# Saved 572/2000 images for class B
# Saved 573/2000 images for class B
# Saved 574/2000 images for class B
# Saved 575/2000 images for class B
# Saved 576/2000 images for class B
# Saved 577/2000 images for class B
# Saved 578/2000 images for class B
# Saved 579/2000 images for class B
# Saved 580/2000 images for class B
# Saved 581/2000 images for class B
# Saved 582/2000 images for class B
# Saved 583/2000 images for class B
# Saved 584/2000 images for class B
# Saved 585/2000 images for class B
# Saved 586/2000 images for class B
# Saved 587/2000 images for class B
# Saved 588/2000 images for class B
# Saved 589/2000 images for class B
# Saved 590/2000 images for class B
# Saved 591/2000 images for class B
# Saved 592/2000 images for class B
# Saved 593/2000 images for class B
# Saved 594/2000 images for class B
# Saved 595/2000 images for class B
# Saved 596/2000 images for class B
# Saved 597/2000 images for class B
# Saved 598/2000 images for class B
# Saved 599/2000 images for class B
# Saved 600/2000 images for class B
# Saved 601/2000 images for class B
# Saved 602/2000 images for class B
# Saved 603/2000 images for class B
# Saved 604/2000 images for class B
# Saved 605/2000 images for class B
# Saved 606/2000 images for class B
# Saved 607/2000 images for class B
# Saved 608/2000 images for class B
# Saved 609/2000 images for class B
# Saved 610/2000 images for class B
# Saved 611/2000 images for class B
# Saved 612/2000 images for class B
# Saved 613/2000 images for class B
# Saved 614/2000 images for class B
# Saved 615/2000 images for class B
# Saved 616/2000 images for class B
# Saved 617/2000 images for class B
# Saved 618/2000 images for class B
# Saved 619/2000 images for class B
# Saved 620/2000 images for class B
# Saved 621/2000 images for class B
# Saved 622/2000 images for class B
# Saved 623/2000 images for class B
# Saved 624/2000 images for class B
# Saved 625/2000 images for class B
# Saved 626/2000 images for class B
# Saved 627/2000 images for class B
# Saved 628/2000 images for class B
# Saved 629/2000 images for class B
# Saved 630/2000 images for class B
# Saved 631/2000 images for class B
# Saved 632/2000 images for class B
# Saved 633/2000 images for class B
# Saved 634/2000 images for class B
# Saved 635/2000 images for class B
# Saved 636/2000 images for class B
# Saved 637/2000 images for class B
# Saved 638/2000 images for class B
# Saved 639/2000 images for class B
# Saved 640/2000 images for class B
# Saved 641/2000 images for class B
# Saved 642/2000 images for class B
# Saved 643/2000 images for class B
# Saved 644/2000 images for class B
# Saved 645/2000 images for class B
# Saved 646/2000 images for class B
# Saved 647/2000 images for class B
# Saved 648/2000 images for class B
# Saved 649/2000 images for class B
# Saved 650/2000 images for class B
# Saved 651/2000 images for class B
# Saved 652/2000 images for class B
# Saved 653/2000 images for class B
# Saved 654/2000 images for class B
# Saved 655/2000 images for class B
# Saved 656/2000 images for class B
# Saved 657/2000 images for class B
# Saved 658/2000 images for class B
# Saved 659/2000 images for class B
# Saved 660/2000 images for class B
# Saved 661/2000 images for class B
# Saved 662/2000 images for class B
# Saved 663/2000 images for class B
# Saved 664/2000 images for class B
# Saved 665/2000 images for class B
# Saved 666/2000 images for class B
# Saved 667/2000 images for class B
# Saved 668/2000 images for class B
# Saved 669/2000 images for class B
# Saved 670/2000 images for class B
# Saved 671/2000 images for class B
# Saved 672/2000 images for class B
# Saved 673/2000 images for class B
# Saved 674/2000 images for class B
# Saved 675/2000 images for class B
# Saved 676/2000 images for class B
# Saved 677/2000 images for class B
# Saved 678/2000 images for class B
# Saved 679/2000 images for class B
# Saved 680/2000 images for class B
# Saved 681/2000 images for class B
# Saved 682/2000 images for class B
# Saved 683/2000 images for class B
# Saved 684/2000 images for class B
# Saved 685/2000 images for class B
# Saved 686/2000 images for class B
# Saved 687/2000 images for class B
# Saved 688/2000 images for class B
# Saved 689/2000 images for class B
# Saved 690/2000 images for class B
# Saved 691/2000 images for class B
# Saved 692/2000 images for class B
# Saved 693/2000 images for class B
# Saved 694/2000 images for class B
# Saved 695/2000 images for class B
# Saved 696/2000 images for class B
# Saved 697/2000 images for class B
# Saved 698/2000 images for class B
# Saved 699/2000 images for class B
# Saved 700/2000 images for class B
# Saved 701/2000 images for class B
# Saved 702/2000 images for class B
# Saved 703/2000 images for class B
# Saved 704/2000 images for class B
# Saved 705/2000 images for class B
# Saved 706/2000 images for class B
# Saved 707/2000 images for class B
# Saved 708/2000 images for class B
# Saved 709/2000 images for class B
# Saved 710/2000 images for class B
# Saved 711/2000 images for class B
# Saved 712/2000 images for class B
# Saved 713/2000 images for class B
# Saved 714/2000 images for class B
# Saved 715/2000 images for class B
# Saved 716/2000 images for class B
# Saved 717/2000 images for class B
# Saved 718/2000 images for class B
# Saved 719/2000 images for class B
# Saved 720/2000 images for class B
# Saved 721/2000 images for class B
# Saved 722/2000 images for class B
# Saved 723/2000 images for class B
# Saved 724/2000 images for class B
# Saved 725/2000 images for class B
# Saved 726/2000 images for class B
# Saved 727/2000 images for class B
# Saved 728/2000 images for class B
# Saved 729/2000 images for class B
# Saved 730/2000 images for class B
# Saved 731/2000 images for class B
# Saved 732/2000 images for class B
# Saved 733/2000 images for class B
# Saved 734/2000 images for class B
# Saved 735/2000 images for class B
# Saved 736/2000 images for class B
# Saved 737/2000 images for class B
# Saved 738/2000 images for class B
# Saved 739/2000 images for class B
# Saved 740/2000 images for class B
# Saved 741/2000 images for class B
# Saved 742/2000 images for class B
# Saved 743/2000 images for class B
# Saved 744/2000 images for class B
# Saved 745/2000 images for class B
# Saved 746/2000 images for class B
# Saved 747/2000 images for class B
# Saved 748/2000 images for class B
# Saved 749/2000 images for class B
# Saved 750/2000 images for class B
# Saved 751/2000 images for class B
# Saved 752/2000 images for class B
# Saved 753/2000 images for class B
# Saved 754/2000 images for class B
# Saved 755/2000 images for class B
# Saved 756/2000 images for class B
# Saved 757/2000 images for class B
# Saved 758/2000 images for class B
# Saved 759/2000 images for class B
# Saved 760/2000 images for class B
# Saved 761/2000 images for class B
# Saved 762/2000 images for class B
# Saved 763/2000 images for class B
# Saved 764/2000 images for class B
# Saved 765/2000 images for class B
# Saved 766/2000 images for class B
# Saved 767/2000 images for class B
# Saved 768/2000 images for class B
# Saved 769/2000 images for class B
# Saved 770/2000 images for class B
# Saved 771/2000 images for class B
# Saved 772/2000 images for class B
# Saved 773/2000 images for class B
# Saved 774/2000 images for class B
# Saved 775/2000 images for class B
# Saved 776/2000 images for class B
# Saved 777/2000 images for class B
# Saved 778/2000 images for class B
# Saved 779/2000 images for class B
# Saved 780/2000 images for class B
# Saved 781/2000 images for class B
# Saved 782/2000 images for class B
# Saved 783/2000 images for class B
# Saved 784/2000 images for class B
# Saved 785/2000 images for class B
# Saved 786/2000 images for class B
# Saved 787/2000 images for class B
# Saved 788/2000 images for class B
# Saved 789/2000 images for class B
# Saved 790/2000 images for class B
# Saved 791/2000 images for class B
# Saved 792/2000 images for class B
# Saved 793/2000 images for class B
# Saved 794/2000 images for class B
# Saved 795/2000 images for class B
# Saved 796/2000 images for class B
# Saved 797/2000 images for class B
# Saved 798/2000 images for class B
# Saved 799/2000 images for class B
# Saved 800/2000 images for class B
# Saved 801/2000 images for class B
# Saved 802/2000 images for class B
# Saved 803/2000 images for class B
# Saved 804/2000 images for class B
# Saved 805/2000 images for class B
# Saved 806/2000 images for class B
# Saved 807/2000 images for class B
# Saved 808/2000 images for class B
# Saved 809/2000 images for class B
# Saved 810/2000 images for class B
# Saved 811/2000 images for class B
# Saved 812/2000 images for class B
# Saved 813/2000 images for class B
# Saved 814/2000 images for class B
# Saved 815/2000 images for class B
# Saved 816/2000 images for class B
# Saved 817/2000 images for class B
# Saved 818/2000 images for class B
# Saved 819/2000 images for class B
# Saved 820/2000 images for class B
# Saved 821/2000 images for class B
# Saved 822/2000 images for class B
# Saved 823/2000 images for class B
# Saved 824/2000 images for class B
# Saved 825/2000 images for class B
# Saved 826/2000 images for class B
# Saved 827/2000 images for class B
# Saved 828/2000 images for class B
# Saved 829/2000 images for class B
# Saved 830/2000 images for class B
# Saved 831/2000 images for class B
# Saved 832/2000 images for class B
# Saved 833/2000 images for class B
# Saved 834/2000 images for class B
# Saved 835/2000 images for class B
# Saved 836/2000 images for class B
# Saved 837/2000 images for class B
# Saved 838/2000 images for class B
# Saved 839/2000 images for class B
# Saved 840/2000 images for class B
# Saved 841/2000 images for class B
# Saved 842/2000 images for class B
# Saved 843/2000 images for class B
# Saved 844/2000 images for class B
# Saved 845/2000 images for class B
# Saved 846/2000 images for class B
# Saved 847/2000 images for class B
# Saved 848/2000 images for class B
# Saved 849/2000 images for class B
# Saved 850/2000 images for class B
# Saved 851/2000 images for class B
# Saved 852/2000 images for class B
# Saved 853/2000 images for class B
# Saved 854/2000 images for class B
# Saved 855/2000 images for class B
# Saved 856/2000 images for class B
# Saved 857/2000 images for class B
# Saved 858/2000 images for class B
# Saved 859/2000 images for class B
# Saved 860/2000 images for class B
# Saved 861/2000 images for class B
# Saved 862/2000 images for class B
# Saved 863/2000 images for class B
# Saved 864/2000 images for class B
# Saved 865/2000 images for class B
# Saved 866/2000 images for class B
# Saved 867/2000 images for class B
# Saved 868/2000 images for class B
# Saved 869/2000 images for class B
# Saved 870/2000 images for class B
# Saved 871/2000 images for class B
# Saved 872/2000 images for class B
# Saved 873/2000 images for class B
# Saved 874/2000 images for class B
# Saved 875/2000 images for class B
# Saved 876/2000 images for class B
# Saved 877/2000 images for class B
# Saved 878/2000 images for class B
# Saved 879/2000 images for class B
# Saved 880/2000 images for class B
# Saved 881/2000 images for class B
# Saved 882/2000 images for class B
# Saved 883/2000 images for class B
# Saved 884/2000 images for class B
# Saved 885/2000 images for class B
# Saved 886/2000 images for class B
# Saved 887/2000 images for class B
# Saved 888/2000 images for class B
# Saved 889/2000 images for class B
# Saved 890/2000 images for class B
# Saved 891/2000 images for class B
# Saved 892/2000 images for class B
# Saved 893/2000 images for class B
# Saved 894/2000 images for class B
# Saved 895/2000 images for class B
# Saved 896/2000 images for class B
# Saved 897/2000 images for class B
# Saved 898/2000 images for class B
# Saved 899/2000 images for class B
# Saved 900/2000 images for class B
# Saved 901/2000 images for class B
# Saved 902/2000 images for class B
# Saved 903/2000 images for class B
# Saved 904/2000 images for class B
# Saved 905/2000 images for class B
# Saved 906/2000 images for class B
# Saved 907/2000 images for class B
# Saved 908/2000 images for class B
# Saved 909/2000 images for class B
# Saved 910/2000 images for class B
# Saved 911/2000 images for class B
# Saved 912/2000 images for class B
# Saved 913/2000 images for class B
# Saved 914/2000 images for class B
# Saved 915/2000 images for class B
# Saved 916/2000 images for class B
# Saved 917/2000 images for class B
# Saved 918/2000 images for class B
# Saved 919/2000 images for class B
# Saved 920/2000 images for class B
# Saved 921/2000 images for class B
# Saved 922/2000 images for class B
# Saved 923/2000 images for class B
# Saved 924/2000 images for class B
# Saved 925/2000 images for class B
# Saved 926/2000 images for class B
# Saved 927/2000 images for class B
# Saved 928/2000 images for class B
# Saved 929/2000 images for class B
# Saved 930/2000 images for class B
# Saved 931/2000 images for class B
# Saved 932/2000 images for class B
# Saved 933/2000 images for class B
# Saved 934/2000 images for class B
# Saved 935/2000 images for class B
# Saved 936/2000 images for class B
# Saved 937/2000 images for class B
# Saved 938/2000 images for class B
# Saved 939/2000 images for class B
# Saved 940/2000 images for class B
# Saved 941/2000 images for class B
# Saved 942/2000 images for class B
# Saved 943/2000 images for class B
# Saved 944/2000 images for class B
# Saved 945/2000 images for class B
# Saved 946/2000 images for class B
# Saved 947/2000 images for class B
# Saved 948/2000 images for class B
# Saved 949/2000 images for class B
# Saved 950/2000 images for class B
# Saved 951/2000 images for class B
# Saved 952/2000 images for class B
# Saved 953/2000 images for class B
# Saved 954/2000 images for class B
# Saved 955/2000 images for class B
# Saved 956/2000 images for class B
# Saved 957/2000 images for class B
# Saved 958/2000 images for class B
# Saved 959/2000 images for class B
# Saved 960/2000 images for class B
# Saved 961/2000 images for class B
# Saved 962/2000 images for class B
# Saved 963/2000 images for class B
# Saved 964/2000 images for class B
# Saved 965/2000 images for class B
# Saved 966/2000 images for class B
# Saved 967/2000 images for class B
# Saved 968/2000 images for class B
# Saved 969/2000 images for class B
# Saved 970/2000 images for class B
# Saved 971/2000 images for class B
# Saved 972/2000 images for class B
# Saved 973/2000 images for class B
# Saved 974/2000 images for class B
# Saved 975/2000 images for class B
# Saved 976/2000 images for class B
# Saved 977/2000 images for class B
# Saved 978/2000 images for class B
# Saved 979/2000 images for class B
# Saved 980/2000 images for class B
# Saved 981/2000 images for class B
# Saved 982/2000 images for class B
# Saved 983/2000 images for class B
# Saved 984/2000 images for class B
# Saved 985/2000 images for class B
# Saved 986/2000 images for class B
# Saved 987/2000 images for class B
# Saved 988/2000 images for class B
# Saved 989/2000 images for class B
# Saved 990/2000 images for class B
# Saved 991/2000 images for class B
# Saved 992/2000 images for class B
# Saved 993/2000 images for class B
# Saved 994/2000 images for class B
# Saved 995/2000 images for class B
# Saved 996/2000 images for class B
# Saved 997/2000 images for class B
# Saved 998/2000 images for class B
# Saved 999/2000 images for class B
# Saved 1000/2000 images for class B
# Saved 1001/2000 images for class B
# Saved 1002/2000 images for class B
# Saved 1003/2000 images for class B
# Saved 1004/2000 images for class B
# Saved 1005/2000 images for class B
# Saved 1006/2000 images for class B
# Saved 1007/2000 images for class B
# Saved 1008/2000 images for class B
# Saved 1009/2000 images for class B
# Saved 1010/2000 images for class B
# Saved 1011/2000 images for class B
# Saved 1012/2000 images for class B
# Saved 1013/2000 images for class B
# Saved 1014/2000 images for class B
# Saved 1015/2000 images for class B
# Saved 1016/2000 images for class B
# Saved 1017/2000 images for class B
# Saved 1018/2000 images for class B
# Saved 1019/2000 images for class B
# Saved 1020/2000 images for class B
# Saved 1021/2000 images for class B
# Saved 1022/2000 images for class B
# Saved 1023/2000 images for class B
# Saved 1024/2000 images for class B
# Saved 1025/2000 images for class B
# Saved 1026/2000 images for class B
# Saved 1027/2000 images for class B
# Saved 1028/2000 images for class B
# Saved 1029/2000 images for class B
# Saved 1030/2000 images for class B
# Saved 1031/2000 images for class B
# Saved 1032/2000 images for class B
# Saved 1033/2000 images for class B
# Saved 1034/2000 images for class B
# Saved 1035/2000 images for class B
# Saved 1036/2000 images for class B
# Saved 1037/2000 images for class B
# Saved 1038/2000 images for class B
# Saved 1039/2000 images for class B
# Saved 1040/2000 images for class B
# Saved 1041/2000 images for class B
# Saved 1042/2000 images for class B
# Saved 1043/2000 images for class B
# Saved 1044/2000 images for class B
# Saved 1045/2000 images for class B
# Saved 1046/2000 images for class B
# Saved 1047/2000 images for class B
# Saved 1048/2000 images for class B
# Saved 1049/2000 images for class B
# Saved 1050/2000 images for class B
# Saved 1051/2000 images for class B
# Saved 1052/2000 images for class B
# Saved 1053/2000 images for class B
# Saved 1054/2000 images for class B
# Saved 1055/2000 images for class B
# Saved 1056/2000 images for class B
# Saved 1057/2000 images for class B
# Saved 1058/2000 images for class B
# Saved 1059/2000 images for class B
# Saved 1060/2000 images for class B
# Saved 1061/2000 images for class B
# Saved 1062/2000 images for class B
# Saved 1063/2000 images for class B
# Saved 1064/2000 images for class B
# Saved 1065/2000 images for class B
# Saved 1066/2000 images for class B
# Saved 1067/2000 images for class B
# Saved 1068/2000 images for class B
# Saved 1069/2000 images for class B
# Saved 1070/2000 images for class B
# Saved 1071/2000 images for class B
# Saved 1072/2000 images for class B
# Saved 1073/2000 images for class B
# Saved 1074/2000 images for class B
# Saved 1075/2000 images for class B
# Saved 1076/2000 images for class B
# Saved 1077/2000 images for class B
# Saved 1078/2000 images for class B
# Saved 1079/2000 images for class B
# Saved 1080/2000 images for class B
# Saved 1081/2000 images for class B
# Saved 1082/2000 images for class B
# Saved 1083/2000 images for class B
# Saved 1084/2000 images for class B
# Saved 1085/2000 images for class B
# Saved 1086/2000 images for class B
# Saved 1087/2000 images for class B
# Saved 1088/2000 images for class B
# Saved 1089/2000 images for class B
# Saved 1090/2000 images for class B
# Saved 1091/2000 images for class B
# Saved 1092/2000 images for class B
# Saved 1093/2000 images for class B
# Saved 1094/2000 images for class B
# Saved 1095/2000 images for class B
# Saved 1096/2000 images for class B
# Saved 1097/2000 images for class B
# Saved 1098/2000 images for class B
# Saved 1099/2000 images for class B
# Saved 1100/2000 images for class B
# Saved 1101/2000 images for class B
# Saved 1102/2000 images for class B
# Saved 1103/2000 images for class B
# Saved 1104/2000 images for class B
# Saved 1105/2000 images for class B
# Saved 1106/2000 images for class B
# Saved 1107/2000 images for class B
# Saved 1108/2000 images for class B
# Saved 1109/2000 images for class B
# Saved 1110/2000 images for class B
# Saved 1111/2000 images for class B
# Saved 1112/2000 images for class B
# Saved 1113/2000 images for class B
# Saved 1114/2000 images for class B
# Saved 1115/2000 images for class B
# Saved 1116/2000 images for class B
# Saved 1117/2000 images for class B
# Saved 1118/2000 images for class B
# Saved 1119/2000 images for class B
# Saved 1120/2000 images for class B
# Saved 1121/2000 images for class B
# Saved 1122/2000 images for class B
# Saved 1123/2000 images for class B
# Saved 1124/2000 images for class B
# Saved 1125/2000 images for class B
# Saved 1126/2000 images for class B
# Saved 1127/2000 images for class B
# Saved 1128/2000 images for class B
# Saved 1129/2000 images for class B
# Saved 1130/2000 images for class B
# Saved 1131/2000 images for class B
# Saved 1132/2000 images for class B
# Saved 1133/2000 images for class B
# Saved 1134/2000 images for class B
# Saved 1135/2000 images for class B
# Saved 1136/2000 images for class B
# Saved 1137/2000 images for class B
# Saved 1138/2000 images for class B
# Saved 1139/2000 images for class B
# Saved 1140/2000 images for class B
# Saved 1141/2000 images for class B
# Saved 1142/2000 images for class B
# Saved 1143/2000 images for class B
# Saved 1144/2000 images for class B
# Saved 1145/2000 images for class B
# Saved 1146/2000 images for class B
# Saved 1147/2000 images for class B
# Saved 1148/2000 images for class B
# Saved 1149/2000 images for class B
# Saved 1150/2000 images for class B
# Saved 1151/2000 images for class B
# Saved 1152/2000 images for class B
# Saved 1153/2000 images for class B
# Saved 1154/2000 images for class B
# Saved 1155/2000 images for class B
# Saved 1156/2000 images for class B
# Saved 1157/2000 images for class B
# Saved 1158/2000 images for class B
# Saved 1159/2000 images for class B
# Saved 1160/2000 images for class B
# Saved 1161/2000 images for class B
# Saved 1162/2000 images for class B
# Saved 1163/2000 images for class B
# Saved 1164/2000 images for class B
# Saved 1165/2000 images for class B
# Saved 1166/2000 images for class B
# Saved 1167/2000 images for class B
# Saved 1168/2000 images for class B
# Saved 1169/2000 images for class B
# Saved 1170/2000 images for class B
# Saved 1171/2000 images for class B
# Saved 1172/2000 images for class B
# Saved 1173/2000 images for class B
# Saved 1174/2000 images for class B
# Saved 1175/2000 images for class B
# Saved 1176/2000 images for class B
# Saved 1177/2000 images for class B
# Saved 1178/2000 images for class B
# Saved 1179/2000 images for class B
# Saved 1180/2000 images for class B
# Saved 1181/2000 images for class B
# Saved 1182/2000 images for class B
# Saved 1183/2000 images for class B
# Saved 1184/2000 images for class B
# Saved 1185/2000 images for class B
# Saved 1186/2000 images for class B
# Saved 1187/2000 images for class B
# Saved 1188/2000 images for class B
# Saved 1189/2000 images for class B
# Saved 1190/2000 images for class B
# Saved 1191/2000 images for class B
# Saved 1192/2000 images for class B
# Saved 1193/2000 images for class B
# Saved 1194/2000 images for class B
# Saved 1195/2000 images for class B
# Saved 1196/2000 images for class B
# Saved 1197/2000 images for class B
# Saved 1198/2000 images for class B
# Saved 1199/2000 images for class B
# Saved 1200/2000 images for class B
# Saved 1201/2000 images for class B
# Saved 1202/2000 images for class B
# Saved 1203/2000 images for class B
# Saved 1204/2000 images for class B
# Saved 1205/2000 images for class B
# Saved 1206/2000 images for class B
# Saved 1207/2000 images for class B
# Saved 1208/2000 images for class B
# Saved 1209/2000 images for class B
# Saved 1210/2000 images for class B
# Saved 1211/2000 images for class B
# Saved 1212/2000 images for class B
# Saved 1213/2000 images for class B
# Saved 1214/2000 images for class B
# Saved 1215/2000 images for class B
# Saved 1216/2000 images for class B
# Saved 1217/2000 images for class B
# Saved 1218/2000 images for class B
# Saved 1219/2000 images for class B
# Saved 1220/2000 images for class B
# Saved 1221/2000 images for class B
# Saved 1222/2000 images for class B
# Saved 1223/2000 images for class B
# Saved 1224/2000 images for class B
# Saved 1225/2000 images for class B
# Saved 1226/2000 images for class B
# Saved 1227/2000 images for class B
# Saved 1228/2000 images for class B
# Saved 1229/2000 images for class B
# Saved 1230/2000 images for class B
# Saved 1231/2000 images for class B
# Saved 1232/2000 images for class B
# Saved 1233/2000 images for class B
# Saved 1234/2000 images for class B
# Saved 1235/2000 images for class B
# Saved 1236/2000 images for class B
# Saved 1237/2000 images for class B
# Saved 1238/2000 images for class B
# Saved 1239/2000 images for class B
# Saved 1240/2000 images for class B
# Saved 1241/2000 images for class B
# Saved 1242/2000 images for class B
# Saved 1243/2000 images for class B
# Saved 1244/2000 images for class B
# Saved 1245/2000 images for class B
# Saved 1246/2000 images for class B
# Saved 1247/2000 images for class B
# Saved 1248/2000 images for class B
# Saved 1249/2000 images for class B
# Saved 1250/2000 images for class B
# Saved 1251/2000 images for class B
# Saved 1252/2000 images for class B
# Saved 1253/2000 images for class B
# Saved 1254/2000 images for class B
# Saved 1255/2000 images for class B
# Saved 1256/2000 images for class B
# Saved 1257/2000 images for class B
# Saved 1258/2000 images for class B
# Saved 1259/2000 images for class B
# Saved 1260/2000 images for class B
# Saved 1261/2000 images for class B
# Saved 1262/2000 images for class B
# Saved 1263/2000 images for class B
# Saved 1264/2000 images for class B
# Saved 1265/2000 images for class B
# Saved 1266/2000 images for class B
# Saved 1267/2000 images for class B
# Saved 1268/2000 images for class B
# Saved 1269/2000 images for class B
# Saved 1270/2000 images for class B
# Saved 1271/2000 images for class B
# Saved 1272/2000 images for class B
# Saved 1273/2000 images for class B
# Saved 1274/2000 images for class B
# Saved 1275/2000 images for class B
# Saved 1276/2000 images for class B
# Saved 1277/2000 images for class B
# Saved 1278/2000 images for class B
# Saved 1279/2000 images for class B
# Saved 1280/2000 images for class B
# Saved 1281/2000 images for class B
# Saved 1282/2000 images for class B
# Saved 1283/2000 images for class B
# Saved 1284/2000 images for class B
# Saved 1285/2000 images for class B
# Saved 1286/2000 images for class B
# Saved 1287/2000 images for class B
# Saved 1288/2000 images for class B
# Saved 1289/2000 images for class B
# Saved 1290/2000 images for class B
# Saved 1291/2000 images for class B
# Saved 1292/2000 images for class B
# Saved 1293/2000 images for class B
# Saved 1294/2000 images for class B
# Saved 1295/2000 images for class B
# Saved 1296/2000 images for class B
# Saved 1297/2000 images for class B
# Saved 1298/2000 images for class B
# Saved 1299/2000 images for class B
# Saved 1300/2000 images for class B
# Saved 1301/2000 images for class B
# Saved 1302/2000 images for class B
# Saved 1303/2000 images for class B
# Saved 1304/2000 images for class B
# Saved 1305/2000 images for class B
# Saved 1306/2000 images for class B
# Saved 1307/2000 images for class B
# Saved 1308/2000 images for class B
# Saved 1309/2000 images for class B
# Saved 1310/2000 images for class B
# Saved 1311/2000 images for class B
# Saved 1312/2000 images for class B
# Saved 1313/2000 images for class B
# Saved 1314/2000 images for class B
# Saved 1315/2000 images for class B
# Saved 1316/2000 images for class B
# Saved 1317/2000 images for class B
# Saved 1318/2000 images for class B
# Saved 1319/2000 images for class B
# Saved 1320/2000 images for class B
# Saved 1321/2000 images for class B
# Saved 1322/2000 images for class B
# Saved 1323/2000 images for class B
# Saved 1324/2000 images for class B
# Saved 1325/2000 images for class B
# Saved 1326/2000 images for class B
# Saved 1327/2000 images for class B
# Saved 1328/2000 images for class B
# Saved 1329/2000 images for class B
# Saved 1330/2000 images for class B
# Saved 1331/2000 images for class B
# Saved 1332/2000 images for class B
# Saved 1333/2000 images for class B
# Saved 1334/2000 images for class B
# Saved 1335/2000 images for class B
# Saved 1336/2000 images for class B
# Saved 1337/2000 images for class B
# Saved 1338/2000 images for class B
# Saved 1339/2000 images for class B
# Saved 1340/2000 images for class B
# Saved 1341/2000 images for class B
# Saved 1342/2000 images for class B
# Saved 1343/2000 images for class B
# Saved 1344/2000 images for class B
# Saved 1345/2000 images for class B
# Saved 1346/2000 images for class B
# Saved 1347/2000 images for class B
# Saved 1348/2000 images for class B
# Saved 1349/2000 images for class B
# Saved 1350/2000 images for class B
# Saved 1351/2000 images for class B
# Saved 1352/2000 images for class B
# Saved 1353/2000 images for class B
# Saved 1354/2000 images for class B
# Saved 1355/2000 images for class B
# Saved 1356/2000 images for class B
# Saved 1357/2000 images for class B
# Saved 1358/2000 images for class B
# Saved 1359/2000 images for class B
# Saved 1360/2000 images for class B
# Saved 1361/2000 images for class B
# Saved 1362/2000 images for class B
# Saved 1363/2000 images for class B
# Saved 1364/2000 images for class B
# Saved 1365/2000 images for class B
# Saved 1366/2000 images for class B
# Saved 1367/2000 images for class B
# Saved 1368/2000 images for class B
# Saved 1369/2000 images for class B
# Saved 1370/2000 images for class B
# Saved 1371/2000 images for class B
# Saved 1372/2000 images for class B
# Saved 1373/2000 images for class B
# Saved 1374/2000 images for class B
# Saved 1375/2000 images for class B
# Saved 1376/2000 images for class B
# Saved 1377/2000 images for class B
# Saved 1378/2000 images for class B
# Saved 1379/2000 images for class B
# Saved 1380/2000 images for class B
# Saved 1381/2000 images for class B
# Saved 1382/2000 images for class B
# Saved 1383/2000 images for class B
# Saved 1384/2000 images for class B
# Saved 1385/2000 images for class B
# Saved 1386/2000 images for class B
# Saved 1387/2000 images for class B
# Saved 1388/2000 images for class B
# Saved 1389/2000 images for class B
# Saved 1390/2000 images for class B
# Saved 1391/2000 images for class B
# Saved 1392/2000 images for class B
# Saved 1393/2000 images for class B
# Saved 1394/2000 images for class B
# Saved 1395/2000 images for class B
# Saved 1396/2000 images for class B
# Saved 1397/2000 images for class B
# Saved 1398/2000 images for class B
# Saved 1399/2000 images for class B
# Saved 1400/2000 images for class B
# Saved 1401/2000 images for class B
# Saved 1402/2000 images for class B
# ...
# Saved 1551/2000 images for class Z
# Saved 1552/2000 images for class Z
# Saved 1553/2000 images for class Z
# Saved 1554/2000 images for class Z
# Saved 1555/2000 images for class Z
# Saved 1556/2000 images for class Z
# Saved 1557/2000 images for class Z
# Saved 1558/2000 images for class Z
# Saved 1559/2000 images for class Z
# Saved 1560/2000 images for class Z
# Saved 1561/2000 images for class Z
# Saved 1562/2000 images for class Z
# Saved 1563/2000 images for class Z
# Saved 1564/2000 images for class Z
# Saved 1565/2000 images for class Z
# Saved 1566/2000 images for class Z
# Saved 1567/2000 images for class Z
# Saved 1568/2000 images for class Z
# Saved 1569/2000 images for class Z
# Saved 1570/2000 images for class Z
# Saved 1571/2000 images for class Z
# Saved 1572/2000 images for class Z
# Saved 1573/2000 images for class Z
# Saved 1574/2000 images for class Z
# Saved 1575/2000 images for class Z
# Saved 1576/2000 images for class Z
# Saved 1577/2000 images for class Z
# Saved 1578/2000 images for class Z
# Saved 1579/2000 images for class Z
# Saved 1580/2000 images for class Z
# Saved 1581/2000 images for class Z
# Saved 1582/2000 images for class Z
# Saved 1583/2000 images for class Z
# Saved 1584/2000 images for class Z
# Saved 1585/2000 images for class Z
# Saved 1586/2000 images for class Z
# Saved 1587/2000 images for class Z
# Saved 1588/2000 images for class Z
# Saved 1589/2000 images for class Z
# Saved 1590/2000 images for class Z
# Saved 1591/2000 images for class Z
# Saved 1592/2000 images for class Z
# Saved 1593/2000 images for class Z
# Saved 1594/2000 images for class Z
# Saved 1595/2000 images for class Z
# Saved 1596/2000 images for class Z
# Saved 1597/2000 images for class Z
# Saved 1598/2000 images for class Z
# Saved 1599/2000 images for class Z
# Saved 1600/2000 images for class Z
# Saved 1601/2000 images for class Z
# Saved 1602/2000 images for class Z
# Saved 1603/2000 images for class Z
# Saved 1604/2000 images for class Z
# Saved 1605/2000 images for class Z
# Saved 1606/2000 images for class Z
# Saved 1607/2000 images for class Z
# Saved 1608/2000 images for class Z
# Saved 1609/2000 images for class Z
# Saved 1610/2000 images for class Z
# Saved 1611/2000 images for class Z
# Saved 1612/2000 images for class Z
# Saved 1613/2000 images for class Z
# Saved 1614/2000 images for class Z
# Saved 1615/2000 images for class Z
# Saved 1616/2000 images for class Z
# Saved 1617/2000 images for class Z
# Saved 1618/2000 images for class Z
# Saved 1619/2000 images for class Z
# Saved 1620/2000 images for class Z
# Saved 1621/2000 images for class Z
# Saved 1622/2000 images for class Z
# Saved 1623/2000 images for class Z
# Saved 1624/2000 images for class Z
# Saved 1625/2000 images for class Z
# Error processing image: could not broadcast input array from shape (901,900,3) into shape (900,900,3)
# Saved 1626/2000 images for class Z
# Saved 1627/2000 images for class Z
# Saved 1628/2000 images for class Z
# Saved 1629/2000 images for class Z
# Saved 1630/2000 images for class Z
# Error processing image: could not broadcast input array from shape (901,900,3) into shape (900,900,3)
# Saved 1631/2000 images for class Z
# Saved 1632/2000 images for class Z
# Saved 1633/2000 images for class Z
# Saved 1634/2000 images for class Z
# Saved 1635/2000 images for class Z
# Saved 1636/2000 images for class Z
# Saved 1637/2000 images for class Z
# Saved 1638/2000 images for class Z
# Saved 1639/2000 images for class Z
# Saved 1640/2000 images for class Z
# Saved 1641/2000 images for class Z
# Saved 1642/2000 images for class Z
# Saved 1643/2000 images for class Z
# Saved 1644/2000 images for class Z
# Saved 1645/2000 images for class Z
# Saved 1646/2000 images for class Z
# Saved 1647/2000 images for class Z
# Saved 1648/2000 images for class Z
# Saved 1649/2000 images for class Z
# Saved 1650/2000 images for class Z
# Saved 1651/2000 images for class Z
# Saved 1652/2000 images for class Z
# Saved 1653/2000 images for class Z
# Saved 1654/2000 images for class Z
# Saved 1655/2000 images for class Z
# Saved 1656/2000 images for class Z
# Saved 1657/2000 images for class Z
# Saved 1658/2000 images for class Z
# Saved 1659/2000 images for class Z
# Saved 1660/2000 images for class Z
# Saved 1661/2000 images for class Z
# Saved 1662/2000 images for class Z
# Saved 1663/2000 images for class Z
# Saved 1664/2000 images for class Z
# Saved 1665/2000 images for class Z
# Saved 1666/2000 images for class Z
# Saved 1667/2000 images for class Z
# Saved 1668/2000 images for class Z
# Saved 1669/2000 images for class Z
# Saved 1670/2000 images for class Z
# Saved 1671/2000 images for class Z
# Saved 1672/2000 images for class Z
# Saved 1673/2000 images for class Z
# Saved 1674/2000 images for class Z
# Saved 1675/2000 images for class Z
# Saved 1676/2000 images for class Z
# Saved 1677/2000 images for class Z
# Saved 1678/2000 images for class Z
# Saved 1679/2000 images for class Z
# Saved 1680/2000 images for class Z
# Saved 1681/2000 images for class Z
# Saved 1682/2000 images for class Z
# Saved 1683/2000 images for class Z
# Saved 1684/2000 images for class Z
# Saved 1685/2000 images for class Z
# Saved 1686/2000 images for class Z
# Saved 1687/2000 images for class Z
# Saved 1688/2000 images for class Z
# Saved 1689/2000 images for class Z
# Saved 1690/2000 images for class Z
# Saved 1691/2000 images for class Z
# Saved 1692/2000 images for class Z
# Saved 1693/2000 images for class Z
# Saved 1694/2000 images for class Z
# Saved 1695/2000 images for class Z
# Saved 1696/2000 images for class Z
# Saved 1697/2000 images for class Z
# Saved 1698/2000 images for class Z
# Saved 1699/2000 images for class Z
# Saved 1700/2000 images for class Z
# Saved 1701/2000 images for class Z
# Saved 1702/2000 images for class Z
# Saved 1703/2000 images for class Z
# Saved 1704/2000 images for class Z
# Saved 1705/2000 images for class Z
# Saved 1706/2000 images for class Z
# Saved 1707/2000 images for class Z
# Saved 1708/2000 images for class Z
# Saved 1709/2000 images for class Z
# Saved 1710/2000 images for class Z
# Saved 1711/2000 images for class Z
# Saved 1712/2000 images for class Z
# Saved 1713/2000 images for class Z
# Saved 1714/2000 images for class Z
# Saved 1715/2000 images for class Z
# Saved 1716/2000 images for class Z
# Saved 1717/2000 images for class Z
# Saved 1718/2000 images for class Z
# Saved 1719/2000 images for class Z
# Saved 1720/2000 images for class Z
# Saved 1721/2000 images for class Z
# Saved 1722/2000 images for class Z
# Saved 1723/2000 images for class Z
# Saved 1724/2000 images for class Z
# Saved 1725/2000 images for class Z
# Saved 1726/2000 images for class Z
# Saved 1727/2000 images for class Z
# Saved 1728/2000 images for class Z
# Saved 1729/2000 images for class Z
# Saved 1730/2000 images for class Z
# Saved 1731/2000 images for class Z
# Saved 1732/2000 images for class Z
# Saved 1733/2000 images for class Z
# Saved 1734/2000 images for class Z
# Saved 1735/2000 images for class Z
# Saved 1736/2000 images for class Z
# Saved 1737/2000 images for class Z
# Saved 1738/2000 images for class Z
# Saved 1739/2000 images for class Z
# Saved 1740/2000 images for class Z
# Saved 1741/2000 images for class Z
# Saved 1742/2000 images for class Z
# Saved 1743/2000 images for class Z
# Saved 1744/2000 images for class Z
# Saved 1745/2000 images for class Z
# Saved 1746/2000 images for class Z
# Saved 1747/2000 images for class Z
# Saved 1748/2000 images for class Z
# Saved 1749/2000 images for class Z
# Saved 1750/2000 images for class Z
# Saved 1751/2000 images for class Z
# Saved 1752/2000 images for class Z
# Saved 1753/2000 images for class Z
# Saved 1754/2000 images for class Z
# Saved 1755/2000 images for class Z
# Saved 1756/2000 images for class Z
# Saved 1757/2000 images for class Z
# Saved 1758/2000 images for class Z
# Saved 1759/2000 images for class Z
# Saved 1760/2000 images for class Z
# Saved 1761/2000 images for class Z
# Saved 1762/2000 images for class Z
# Saved 1763/2000 images for class Z
# Saved 1764/2000 images for class Z
# Saved 1765/2000 images for class Z
# Saved 1766/2000 images for class Z
# Saved 1767/2000 images for class Z
# Saved 1768/2000 images for class Z
# Saved 1769/2000 images for class Z
# Saved 1770/2000 images for class Z
# Saved 1771/2000 images for class Z
# Saved 1772/2000 images for class Z
# Saved 1773/2000 images for class Z
# Saved 1774/2000 images for class Z
# Saved 1775/2000 images for class Z
# Saved 1776/2000 images for class Z
# Saved 1777/2000 images for class Z
# Saved 1778/2000 images for class Z
# Saved 1779/2000 images for class Z
# Saved 1780/2000 images for class Z
# Saved 1781/2000 images for class Z
# Saved 1782/2000 images for class Z
# Saved 1783/2000 images for class Z
# Saved 1784/2000 images for class Z
# Saved 1785/2000 images for class Z
# Saved 1786/2000 images for class Z
# Saved 1787/2000 images for class Z
# Saved 1788/2000 images for class Z
# Saved 1789/2000 images for class Z
# Saved 1790/2000 images for class Z
# Saved 1791/2000 images for class Z
# Saved 1792/2000 images for class Z
# Saved 1793/2000 images for class Z
# Saved 1794/2000 images for class Z
# Saved 1795/2000 images for class Z
# Saved 1796/2000 images for class Z
# Saved 1797/2000 images for class Z
# Saved 1798/2000 images for class Z
# Saved 1799/2000 images for class Z
# Saved 1800/2000 images for class Z
# Saved 1801/2000 images for class Z
# Saved 1802/2000 images for class Z
# Saved 1803/2000 images for class Z
# Saved 1804/2000 images for class Z
# Saved 1805/2000 images for class Z
# Saved 1806/2000 images for class Z
# Saved 1807/2000 images for class Z
# Saved 1808/2000 images for class Z
# Saved 1809/2000 images for class Z
# Saved 1810/2000 images for class Z
# Saved 1811/2000 images for class Z
# Saved 1812/2000 images for class Z
# Saved 1813/2000 images for class Z
# Saved 1814/2000 images for class Z
# Saved 1815/2000 images for class Z
# Saved 1816/2000 images for class Z
# Saved 1817/2000 images for class Z
# Saved 1818/2000 images for class Z
# Saved 1819/2000 images for class Z
# Saved 1820/2000 images for class Z
# Saved 1821/2000 images for class Z
# Saved 1822/2000 images for class Z
# Saved 1823/2000 images for class Z
# Saved 1824/2000 images for class Z
# Saved 1825/2000 images for class Z
# Saved 1826/2000 images for class Z
# Saved 1827/2000 images for class Z
# Saved 1828/2000 images for class Z
# Saved 1829/2000 images for class Z
# Saved 1830/2000 images for class Z
# Saved 1831/2000 images for class Z
# Saved 1832/2000 images for class Z
# Saved 1833/2000 images for class Z
# Saved 1834/2000 images for class Z
# Saved 1835/2000 images for class Z
# Saved 1836/2000 images for class Z
# Saved 1837/2000 images for class Z
# Saved 1838/2000 images for class Z
# Saved 1839/2000 images for class Z
# Saved 1840/2000 images for class Z
# Saved 1841/2000 images for class Z
# Saved 1842/2000 images for class Z
# Saved 1843/2000 images for class Z
# Saved 1844/2000 images for class Z
# Saved 1845/2000 images for class Z
# Saved 1846/2000 images for class Z
# Saved 1847/2000 images for class Z
# Saved 1848/2000 images for class Z
# Saved 1849/2000 images for class Z
# Saved 1850/2000 images for class Z
# Saved 1851/2000 images for class Z
# Saved 1852/2000 images for class Z
# Saved 1853/2000 images for class Z
# Saved 1854/2000 images for class Z
# Saved 1855/2000 images for class Z
# Saved 1856/2000 images for class Z
# Saved 1857/2000 images for class Z
# Saved 1858/2000 images for class Z
# Saved 1859/2000 images for class Z
# Saved 1860/2000 images for class Z
# Saved 1861/2000 images for class Z
# Saved 1862/2000 images for class Z
# Saved 1863/2000 images for class Z
# Saved 1864/2000 images for class Z
# Saved 1865/2000 images for class Z
# Saved 1866/2000 images for class Z
# Saved 1867/2000 images for class Z
# Saved 1868/2000 images for class Z
# Saved 1869/2000 images for class Z
# Saved 1870/2000 images for class Z
# Saved 1871/2000 images for class Z
# Saved 1872/2000 images for class Z
# Saved 1873/2000 images for class Z
# Saved 1874/2000 images for class Z
# Saved 1875/2000 images for class Z
# Saved 1876/2000 images for class Z
# Saved 1877/2000 images for class Z
# Saved 1878/2000 images for class Z
# Saved 1879/2000 images for class Z
# Saved 1880/2000 images for class Z
# Saved 1881/2000 images for class Z
# Saved 1882/2000 images for class Z
# Saved 1883/2000 images for class Z
# Saved 1884/2000 images for class Z
# Saved 1885/2000 images for class Z
# Saved 1886/2000 images for class Z
# Saved 1887/2000 images for class Z
# Saved 1888/2000 images for class Z
# Saved 1889/2000 images for class Z
# Saved 1890/2000 images for class Z
# Saved 1891/2000 images for class Z
# Saved 1892/2000 images for class Z
# Saved 1893/2000 images for class Z
# Saved 1894/2000 images for class Z
# Saved 1895/2000 images for class Z
# Saved 1896/2000 images for class Z
# Saved 1897/2000 images for class Z
# Saved 1898/2000 images for class Z
# Saved 1899/2000 images for class Z
# Saved 1900/2000 images for class Z
# Saved 1901/2000 images for class Z
# Saved 1902/2000 images for class Z
# Saved 1903/2000 images for class Z
# Saved 1904/2000 images for class Z
# Saved 1905/2000 images for class Z
# Saved 1906/2000 images for class Z
# Saved 1907/2000 images for class Z
# Saved 1908/2000 images for class Z
# Saved 1909/2000 images for class Z
# Saved 1910/2000 images for class Z
# Saved 1911/2000 images for class Z
# Saved 1912/2000 images for class Z
# Saved 1913/2000 images for class Z
# Saved 1914/2000 images for class Z
# Saved 1915/2000 images for class Z
# Saved 1916/2000 images for class Z
# Saved 1917/2000 images for class Z
# Saved 1918/2000 images for class Z
# Saved 1919/2000 images for class Z
# Saved 1920/2000 images for class Z
# Saved 1921/2000 images for class Z
# Saved 1922/2000 images for class Z
# Saved 1923/2000 images for class Z
# Saved 1924/2000 images for class Z
# Saved 1925/2000 images for class Z
# Saved 1926/2000 images for class Z
# Saved 1927/2000 images for class Z
# Saved 1928/2000 images for class Z
# Saved 1929/2000 images for class Z
# Saved 1930/2000 images for class Z
# Saved 1931/2000 images for class Z
# Saved 1932/2000 images for class Z
# Saved 1933/2000 images for class Z
# Saved 1934/2000 images for class Z
# Saved 1935/2000 images for class Z
# Saved 1936/2000 images for class Z
# Saved 1937/2000 images for class Z
# Saved 1938/2000 images for class Z
# Saved 1939/2000 images for class Z
# Saved 1940/2000 images for class Z
# Saved 1941/2000 images for class Z
# Saved 1942/2000 images for class Z
# Saved 1943/2000 images for class Z
# Saved 1944/2000 images for class Z
# Saved 1945/2000 images for class Z
# Saved 1946/2000 images for class Z
# Saved 1947/2000 images for class Z
# Saved 1948/2000 images for class Z
# Saved 1949/2000 images for class Z
# Saved 1950/2000 images for class Z
# Saved 1951/2000 images for class Z
# Saved 1952/2000 images for class Z
# Saved 1953/2000 images for class Z
# Saved 1954/2000 images for class Z
# Saved 1955/2000 images for class Z
# Saved 1956/2000 images for class Z
# Saved 1957/2000 images for class Z
# Saved 1958/2000 images for class Z
# Saved 1959/2000 images for class Z
# Saved 1960/2000 images for class Z
# Saved 1961/2000 images for class Z
# Saved 1962/2000 images for class Z
# Saved 1963/2000 images for class Z
# Saved 1964/2000 images for class Z
# Saved 1965/2000 images for class Z
# Saved 1966/2000 images for class Z
# Saved 1967/2000 images for class Z
# Saved 1968/2000 images for class Z
# Saved 1969/2000 images for class Z
# Saved 1970/2000 images for class Z
# Saved 1971/2000 images for class Z
# Saved 1972/2000 images for class Z
# Saved 1973/2000 images for class Z
# Saved 1974/2000 images for class Z
# Saved 1975/2000 images for class Z
# Saved 1976/2000 images for class Z
# Saved 1977/2000 images for class Z
# Saved 1978/2000 images for class Z
# Saved 1979/2000 images for class Z
# Saved 1980/2000 images for class Z
# Saved 1981/2000 images for class Z
# Saved 1982/2000 images for class Z
# Saved 1983/2000 images for class Z
# Saved 1984/2000 images for class Z
# Saved 1985/2000 images for class Z
# Saved 1986/2000 images for class Z
# Saved 1987/2000 images for class Z
# Saved 1988/2000 images for class Z
# Saved 1989/2000 images for class Z
# Saved 1990/2000 images for class Z
# Saved 1991/2000 images for class Z
# Saved 1992/2000 images for class Z
# Saved 1993/2000 images for class Z
# Saved 1994/2000 images for class Z
# Saved 1995/2000 images for class Z
# Saved 1996/2000 images for class Z
# Saved 1997/2000 images for class Z
# Saved 1998/2000 images for class Z
# Saved 1999/2000 images for class Z
# Saved 2000/2000 images for class Z
# Completed collection for Z.

# %%
# Initialize webcam
cap = cv2.VideoCapture(0)

# Initialize hand detector
detector = HandDetector(maxHands=1)

# Constants
offset = 20
imgSize = 900
baseFolder = "C:/Users/User/OneDrive/Documents/SignLanguageApp/SLangDataset/ownData/training"
captureInterval = 0.001  # Interval between captures in seconds

# Process only the letter 'Space'
className = 'Space'
print(f"Starting collection for class: {className}")
folder = os.path.join(baseFolder, className)
os.makedirs(folder, exist_ok=True)

# Initialize counter for the current class
counter = 0
maxImages = 2000

collecting = False

while counter < maxImages:
    success, img = cap.read()
    if not success:
        print("Failed to access camera.")
        break

    # Detect hands in the image
    hands, img = detector.findHands(img)
    if hands:
        hand = hands[0]
        x, y, w, h = hand['bbox']

        # Create a white canvas
        imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 255

        # Crop the image around the detected hand
        imgCrop = img[y - offset:y + h + offset, x - offset:x + w + offset]

        # Prevent errors from invalid crop boundaries
        if imgCrop.size == 0:
            continue

        aspectRatio = h / w

        try:
            if aspectRatio > 1:
                # Height is greater than width
                k = imgSize / h
                wCal = math.ceil(k * w)
                imgResize = cv2.resize(imgCrop, (wCal, imgSize))
                wGap = math.ceil((imgSize - wCal) / 2)
                imgWhite[:, wGap:wCal + wGap] = imgResize
            else:
                # Width is greater than height
                k = imgSize / w
                hCal = math.ceil(k * h)
                imgResize = cv2.resize(imgCrop, (imgSize, hCal))
                hGap = math.ceil((imgSize - hCal) / 2)
                imgWhite[hGap:hCal + hGap, :] = imgResize

            # Display the processed images
            cv2.imshow("ImageCrop", imgCrop)
            cv2.imshow("ImageWhite", imgWhite)
        except Exception as e:
            print(f"Error processing image: {e}")
            continue

        if collecting:
            # Save the image automatically
            counter += 1
            filePath = os.path.join(folder, f"{className.lower()}_{counter}.jpg")
            cv2.imwrite(filePath, imgWhite)
            print(f"Saved {counter}/{maxImages} images for class {className}")

    # Display the original image
    cv2.imshow("Image", img)

    # Check for key press
    key = cv2.waitKey(1)
    if key == ord('q'):
        collecting = True

    # Wait for the interval
    time.sleep(captureInterval)

print(f"Completed collection for {className}.")
input("Press 'Enter' to exit.")

# Release the webcam and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Starting collection for class: Space
# Error processing image: could not broadcast input array from shape (901,900,3) into shape (900,900,3)
# Error processing image: could not broadcast input array from shape (901,900,3) into shape (900,900,3)
# Error processing image: could not broadcast input array from shape (901,900,3) into shape (900,900,3)
# Error processing image: could not broadcast input array from shape (901,900,3) into shape (900,900,3)
# Error processing image: could not broadcast input array from shape (901,900,3) into shape (900,900,3)
# Error processing image: could not broadcast input array from shape (901,900,3) into shape (900,900,3)
# Saved 1/2000 images for class Space
# Saved 2/2000 images for class Space
# Saved 3/2000 images for class Space
# Saved 4/2000 images for class Space
# Saved 5/2000 images for class Space
# Saved 6/2000 images for class Space
# Saved 7/2000 images for class Space
# Saved 8/2000 images for class Space
# Saved 9/2000 images for class Space
# Saved 10/2000 images for class Space
# Saved 11/2000 images for class Space
# Saved 12/2000 images for class Space
# Saved 13/2000 images for class Space
# Saved 14/2000 images for class Space
# Saved 15/2000 images for class Space
# Saved 16/2000 images for class Space
# Saved 17/2000 images for class Space
# Saved 18/2000 images for class Space
# Saved 19/2000 images for class Space
# Saved 20/2000 images for class Space
# Saved 21/2000 images for class Space
# Saved 22/2000 images for class Space
# Saved 23/2000 images for class Space
# Saved 24/2000 images for class Space
# Saved 25/2000 images for class Space
# Saved 26/2000 images for class Space
# Saved 27/2000 images for class Space
# Saved 28/2000 images for class Space
# Saved 29/2000 images for class Space
# Saved 30/2000 images for class Space
# Saved 31/2000 images for class Space
# Saved 32/2000 images for class Space
# Saved 33/2000 images for class Space
# Saved 34/2000 images for class Space
# Saved 35/2000 images for class Space
# Saved 36/2000 images for class Space
# Saved 37/2000 images for class Space
# Saved 38/2000 images for class Space
# Saved 39/2000 images for class Space
# Saved 40/2000 images for class Space
# Saved 41/2000 images for class Space
# Saved 42/2000 images for class Space
# Saved 43/2000 images for class Space
# Saved 44/2000 images for class Space
# Saved 45/2000 images for class Space
# Saved 46/2000 images for class Space
# Saved 47/2000 images for class Space
# Saved 48/2000 images for class Space
# Saved 49/2000 images for class Space
# Saved 50/2000 images for class Space
# Saved 51/2000 images for class Space
# Saved 52/2000 images for class Space
# Saved 53/2000 images for class Space
# Saved 54/2000 images for class Space
# Saved 55/2000 images for class Space
# Saved 56/2000 images for class Space
# Saved 57/2000 images for class Space
# Saved 58/2000 images for class Space
# Saved 59/2000 images for class Space
# Saved 60/2000 images for class Space
# Saved 61/2000 images for class Space
# Saved 62/2000 images for class Space
# Saved 63/2000 images for class Space
# Saved 64/2000 images for class Space
# Saved 65/2000 images for class Space
# Saved 66/2000 images for class Space
# Saved 67/2000 images for class Space
# Saved 68/2000 images for class Space
# Saved 69/2000 images for class Space
# Saved 70/2000 images for class Space
# Saved 71/2000 images for class Space
# Saved 72/2000 images for class Space
# Saved 73/2000 images for class Space
# Saved 74/2000 images for class Space
# Saved 75/2000 images for class Space
# Saved 76/2000 images for class Space
# Saved 77/2000 images for class Space
# Saved 78/2000 images for class Space
# Saved 79/2000 images for class Space
# Saved 80/2000 images for class Space
# Saved 81/2000 images for class Space
# Saved 82/2000 images for class Space
# Saved 83/2000 images for class Space
# Saved 84/2000 images for class Space
# Saved 85/2000 images for class Space
# Saved 86/2000 images for class Space
# Saved 87/2000 images for class Space
# Saved 88/2000 images for class Space
# Saved 89/2000 images for class Space
# Saved 90/2000 images for class Space
# Saved 91/2000 images for class Space
# Saved 92/2000 images for class Space
# Saved 93/2000 images for class Space
# Saved 94/2000 images for class Space
# Saved 95/2000 images for class Space
# Saved 96/2000 images for class Space
# Saved 97/2000 images for class Space
# Saved 98/2000 images for class Space
# Saved 99/2000 images for class Space
# Saved 100/2000 images for class Space
# Saved 101/2000 images for class Space
# Saved 102/2000 images for class Space
# Saved 103/2000 images for class Space
# Saved 104/2000 images for class Space
# Saved 105/2000 images for class Space
# Saved 106/2000 images for class Space
# Saved 107/2000 images for class Space
# Saved 108/2000 images for class Space
# Saved 109/2000 images for class Space
# Saved 110/2000 images for class Space
# Saved 111/2000 images for class Space
# Saved 112/2000 images for class Space
# Saved 113/2000 images for class Space
# Saved 114/2000 images for class Space
# Saved 115/2000 images for class Space
# Saved 116/2000 images for class Space
# Saved 117/2000 images for class Space
# Saved 118/2000 images for class Space
# Saved 119/2000 images for class Space
# Saved 120/2000 images for class Space
# Saved 121/2000 images for class Space
# Saved 122/2000 images for class Space
# Saved 123/2000 images for class Space
# Saved 124/2000 images for class Space
# Saved 125/2000 images for class Space
# Saved 126/2000 images for class Space
# Saved 127/2000 images for class Space
# Saved 128/2000 images for class Space
# Saved 129/2000 images for class Space
# Saved 130/2000 images for class Space
# Saved 131/2000 images for class Space
# Saved 132/2000 images for class Space
# Saved 133/2000 images for class Space
# Saved 134/2000 images for class Space
# Saved 135/2000 images for class Space
# Saved 136/2000 images for class Space
# Saved 137/2000 images for class Space
# Saved 138/2000 images for class Space
# Saved 139/2000 images for class Space
# Saved 140/2000 images for class Space
# Saved 141/2000 images for class Space
# Saved 142/2000 images for class Space
# Saved 143/2000 images for class Space
# Saved 144/2000 images for class Space
# Saved 145/2000 images for class Space
# Saved 146/2000 images for class Space
# Saved 147/2000 images for class Space
# Saved 148/2000 images for class Space
# Saved 149/2000 images for class Space
# Saved 150/2000 images for class Space
# Saved 151/2000 images for class Space
# Saved 152/2000 images for class Space
# Saved 153/2000 images for class Space
# Saved 154/2000 images for class Space
# Saved 155/2000 images for class Space
# Saved 156/2000 images for class Space
# Saved 157/2000 images for class Space
# Saved 158/2000 images for class Space
# Saved 159/2000 images for class Space
# Saved 160/2000 images for class Space
# Saved 161/2000 images for class Space
# Saved 162/2000 images for class Space
# Saved 163/2000 images for class Space
# Saved 164/2000 images for class Space
# Saved 165/2000 images for class Space
# Saved 166/2000 images for class Space
# Saved 167/2000 images for class Space
# Saved 168/2000 images for class Space
# Saved 169/2000 images for class Space
# Saved 170/2000 images for class Space
# Saved 171/2000 images for class Space
# Saved 172/2000 images for class Space
# Saved 173/2000 images for class Space
# Saved 174/2000 images for class Space
# Saved 175/2000 images for class Space
# Saved 176/2000 images for class Space
# Saved 177/2000 images for class Space
# Saved 178/2000 images for class Space
# Saved 179/2000 images for class Space
# Saved 180/2000 images for class Space
# Saved 181/2000 images for class Space
# Saved 182/2000 images for class Space
# Saved 183/2000 images for class Space
# Saved 184/2000 images for class Space
# Saved 185/2000 images for class Space
# Saved 186/2000 images for class Space
# Saved 187/2000 images for class Space
# Saved 188/2000 images for class Space
# Saved 189/2000 images for class Space
# Saved 190/2000 images for class Space
# Saved 191/2000 images for class Space
# Saved 192/2000 images for class Space
# Saved 193/2000 images for class Space
# Saved 194/2000 images for class Space
# Saved 195/2000 images for class Space
# Saved 196/2000 images for class Space
# Saved 197/2000 images for class Space
# Saved 198/2000 images for class Space
# Saved 199/2000 images for class Space
# Saved 200/2000 images for class Space
# Saved 201/2000 images for class Space
# Saved 202/2000 images for class Space
# Saved 203/2000 images for class Space
# Saved 204/2000 images for class Space
# Saved 205/2000 images for class Space
# Saved 206/2000 images for class Space
# Saved 207/2000 images for class Space
# Saved 208/2000 images for class Space
# Saved 209/2000 images for class Space
# Saved 210/2000 images for class Space
# Saved 211/2000 images for class Space
# Saved 212/2000 images for class Space
# Saved 213/2000 images for class Space
# Saved 214/2000 images for class Space
# Saved 215/2000 images for class Space
# Saved 216/2000 images for class Space
# Saved 217/2000 images for class Space
# Saved 218/2000 images for class Space
# Saved 219/2000 images for class Space
# Saved 220/2000 images for class Space
# Saved 221/2000 images for class Space
# Saved 222/2000 images for class Space
# Saved 223/2000 images for class Space
# Saved 224/2000 images for class Space
# Saved 225/2000 images for class Space
# Saved 226/2000 images for class Space
# Saved 227/2000 images for class Space
# Saved 228/2000 images for class Space
# Saved 229/2000 images for class Space
# Saved 230/2000 images for class Space
# Saved 231/2000 images for class Space
# Saved 232/2000 images for class Space
# Saved 233/2000 images for class Space
# Saved 234/2000 images for class Space
# Saved 235/2000 images for class Space
# Saved 236/2000 images for class Space
# Saved 237/2000 images for class Space
# Saved 238/2000 images for class Space
# Saved 239/2000 images for class Space
# Saved 240/2000 images for class Space
# Saved 241/2000 images for class Space
# Saved 242/2000 images for class Space
# Saved 243/2000 images for class Space
# Saved 244/2000 images for class Space
# Saved 245/2000 images for class Space
# Saved 246/2000 images for class Space
# Saved 247/2000 images for class Space
# Saved 248/2000 images for class Space
# Saved 249/2000 images for class Space
# Saved 250/2000 images for class Space
# Saved 251/2000 images for class Space
# Saved 252/2000 images for class Space
# Saved 253/2000 images for class Space
# Saved 254/2000 images for class Space
# Saved 255/2000 images for class Space
# Saved 256/2000 images for class Space
# Saved 257/2000 images for class Space
# Saved 258/2000 images for class Space
# Saved 259/2000 images for class Space
# Saved 260/2000 images for class Space
# Saved 261/2000 images for class Space
# Saved 262/2000 images for class Space
# Saved 263/2000 images for class Space
# Saved 264/2000 images for class Space
# Saved 265/2000 images for class Space
# Saved 266/2000 images for class Space
# Saved 267/2000 images for class Space
# Saved 268/2000 images for class Space
# Saved 269/2000 images for class Space
# Saved 270/2000 images for class Space
# Saved 271/2000 images for class Space
# Saved 272/2000 images for class Space
# Saved 273/2000 images for class Space
# Saved 274/2000 images for class Space
# Saved 275/2000 images for class Space
# Saved 276/2000 images for class Space
# Saved 277/2000 images for class Space
# Saved 278/2000 images for class Space
# Saved 279/2000 images for class Space
# Saved 280/2000 images for class Space
# Saved 281/2000 images for class Space
# Saved 282/2000 images for class Space
# Saved 283/2000 images for class Space
# Saved 284/2000 images for class Space
# Saved 285/2000 images for class Space
# Saved 286/2000 images for class Space
# Saved 287/2000 images for class Space
# Saved 288/2000 images for class Space
# Saved 289/2000 images for class Space
# Saved 290/2000 images for class Space
# Saved 291/2000 images for class Space
# Saved 292/2000 images for class Space
# Saved 293/2000 images for class Space
# Saved 294/2000 images for class Space
# Saved 295/2000 images for class Space
# Saved 296/2000 images for class Space
# Saved 297/2000 images for class Space
# Saved 298/2000 images for class Space
# Saved 299/2000 images for class Space
# Saved 300/2000 images for class Space
# Saved 301/2000 images for class Space
# Saved 302/2000 images for class Space
# Saved 303/2000 images for class Space
# Saved 304/2000 images for class Space
# Saved 305/2000 images for class Space
# Saved 306/2000 images for class Space
# Saved 307/2000 images for class Space
# Saved 308/2000 images for class Space
# Saved 309/2000 images for class Space
# Saved 310/2000 images for class Space
# Saved 311/2000 images for class Space
# Saved 312/2000 images for class Space
# Saved 313/2000 images for class Space
# Saved 314/2000 images for class Space
# Saved 315/2000 images for class Space
# Saved 316/2000 images for class Space
# Saved 317/2000 images for class Space
# Saved 318/2000 images for class Space
# Saved 319/2000 images for class Space
# Saved 320/2000 images for class Space
# Saved 321/2000 images for class Space
# Saved 322/2000 images for class Space
# Saved 323/2000 images for class Space
# Saved 324/2000 images for class Space
# Saved 325/2000 images for class Space
# Saved 326/2000 images for class Space
# Saved 327/2000 images for class Space
# Saved 328/2000 images for class Space
# Saved 329/2000 images for class Space
# Saved 330/2000 images for class Space
# Saved 331/2000 images for class Space
# Saved 332/2000 images for class Space
# Saved 333/2000 images for class Space
# Saved 334/2000 images for class Space
# Saved 335/2000 images for class Space
# Saved 336/2000 images for class Space
# Saved 337/2000 images for class Space
# Saved 338/2000 images for class Space
# Saved 339/2000 images for class Space
# Saved 340/2000 images for class Space
# Saved 341/2000 images for class Space
# Saved 342/2000 images for class Space
# Saved 343/2000 images for class Space
# Saved 344/2000 images for class Space
# Saved 345/2000 images for class Space
# Saved 346/2000 images for class Space
# Saved 347/2000 images for class Space
# Saved 348/2000 images for class Space
# Saved 349/2000 images for class Space
# Saved 350/2000 images for class Space
# Saved 351/2000 images for class Space
# Saved 352/2000 images for class Space
# Saved 353/2000 images for class Space
# Saved 354/2000 images for class Space
# Saved 355/2000 images for class Space
# Saved 356/2000 images for class Space
# Saved 357/2000 images for class Space
# Saved 358/2000 images for class Space
# Saved 359/2000 images for class Space
# Saved 360/2000 images for class Space
# Saved 361/2000 images for class Space
# Saved 362/2000 images for class Space
# Saved 363/2000 images for class Space
# Saved 364/2000 images for class Space
# Saved 365/2000 images for class Space
# Saved 366/2000 images for class Space
# Saved 367/2000 images for class Space
# Saved 368/2000 images for class Space
# Saved 369/2000 images for class Space
# Saved 370/2000 images for class Space
# Saved 371/2000 images for class Space
# Saved 372/2000 images for class Space
# Saved 373/2000 images for class Space
# Saved 374/2000 images for class Space
# Saved 375/2000 images for class Space
# Saved 376/2000 images for class Space
# Saved 377/2000 images for class Space
# Saved 378/2000 images for class Space
# Saved 379/2000 images for class Space
# Saved 380/2000 images for class Space
# Saved 381/2000 images for class Space
# Saved 382/2000 images for class Space
# Saved 383/2000 images for class Space
# Saved 384/2000 images for class Space
# Saved 385/2000 images for class Space
# Saved 386/2000 images for class Space
# Saved 387/2000 images for class Space
# Saved 388/2000 images for class Space
# Saved 389/2000 images for class Space
# Saved 390/2000 images for class Space
# Saved 391/2000 images for class Space
# Saved 392/2000 images for class Space
# Saved 393/2000 images for class Space
# Saved 394/2000 images for class Space
# Saved 395/2000 images for class Space
# Saved 396/2000 images for class Space
# Saved 397/2000 images for class Space
# Saved 398/2000 images for class Space
# Saved 399/2000 images for class Space
# Saved 400/2000 images for class Space
# Saved 401/2000 images for class Space
# Saved 402/2000 images for class Space
# Saved 403/2000 images for class Space
# Saved 404/2000 images for class Space
# Saved 405/2000 images for class Space
# Saved 406/2000 images for class Space
# Saved 407/2000 images for class Space
# Saved 408/2000 images for class Space
# Saved 409/2000 images for class Space
# Saved 410/2000 images for class Space
# Saved 411/2000 images for class Space
# Saved 412/2000 images for class Space
# Saved 413/2000 images for class Space
# Saved 414/2000 images for class Space
# Saved 415/2000 images for class Space
# Saved 416/2000 images for class Space
# Saved 417/2000 images for class Space
# Saved 418/2000 images for class Space
# Saved 419/2000 images for class Space
# Saved 420/2000 images for class Space
# Saved 421/2000 images for class Space
# Saved 422/2000 images for class Space
# Saved 423/2000 images for class Space
# Saved 424/2000 images for class Space
# Saved 425/2000 images for class Space
# Saved 426/2000 images for class Space
# Saved 427/2000 images for class Space
# Saved 428/2000 images for class Space
# Saved 429/2000 images for class Space
# Saved 430/2000 images for class Space
# Saved 431/2000 images for class Space
# Saved 432/2000 images for class Space
# Saved 433/2000 images for class Space
# Saved 434/2000 images for class Space
# Saved 435/2000 images for class Space
# Saved 436/2000 images for class Space
# Saved 437/2000 images for class Space
# Saved 438/2000 images for class Space
# Saved 439/2000 images for class Space
# Saved 440/2000 images for class Space
# Saved 441/2000 images for class Space
# Saved 442/2000 images for class Space
# Saved 443/2000 images for class Space
# Saved 444/2000 images for class Space
# Saved 445/2000 images for class Space
# Saved 446/2000 images for class Space
# Saved 447/2000 images for class Space
# Saved 448/2000 images for class Space
# Saved 449/2000 images for class Space
# Saved 450/2000 images for class Space
# Saved 451/2000 images for class Space
# Saved 452/2000 images for class Space
# Saved 453/2000 images for class Space
# Saved 454/2000 images for class Space
# Saved 455/2000 images for class Space
# Saved 456/2000 images for class Space
# Saved 457/2000 images for class Space
# Saved 458/2000 images for class Space
# Saved 459/2000 images for class Space
# Saved 460/2000 images for class Space
# Saved 461/2000 images for class Space
# Saved 462/2000 images for class Space
# Saved 463/2000 images for class Space
# Saved 464/2000 images for class Space
# Saved 465/2000 images for class Space
# Saved 466/2000 images for class Space
# Saved 467/2000 images for class Space
# Saved 468/2000 images for class Space
# Saved 469/2000 images for class Space
# Saved 470/2000 images for class Space
# Saved 471/2000 images for class Space
# Saved 472/2000 images for class Space
# Saved 473/2000 images for class Space
# Saved 474/2000 images for class Space
# Saved 475/2000 images for class Space
# Saved 476/2000 images for class Space
# Saved 477/2000 images for class Space
# Saved 478/2000 images for class Space
# Saved 479/2000 images for class Space
# Saved 480/2000 images for class Space
# Saved 481/2000 images for class Space
# Saved 482/2000 images for class Space
# Saved 483/2000 images for class Space
# Saved 484/2000 images for class Space
# Saved 485/2000 images for class Space
# Saved 486/2000 images for class Space
# Saved 487/2000 images for class Space
# Saved 488/2000 images for class Space
# Saved 489/2000 images for class Space
# Saved 490/2000 images for class Space
# Saved 491/2000 images for class Space
# Saved 492/2000 images for class Space
# Saved 493/2000 images for class Space
# Saved 494/2000 images for class Space
# Saved 495/2000 images for class Space
# Saved 496/2000 images for class Space
# Saved 497/2000 images for class Space
# Saved 498/2000 images for class Space
# Saved 499/2000 images for class Space
# Saved 500/2000 images for class Space
# Saved 501/2000 images for class Space
# Saved 502/2000 images for class Space
# Saved 503/2000 images for class Space
# Saved 504/2000 images for class Space
# Saved 505/2000 images for class Space
# Saved 506/2000 images for class Space
# Saved 507/2000 images for class Space
# Saved 508/2000 images for class Space
# Saved 509/2000 images for class Space
# Saved 510/2000 images for class Space
# Saved 511/2000 images for class Space
# Saved 512/2000 images for class Space
# Saved 513/2000 images for class Space
# Saved 514/2000 images for class Space
# Saved 515/2000 images for class Space
# Saved 516/2000 images for class Space
# Saved 517/2000 images for class Space
# Saved 518/2000 images for class Space
# Saved 519/2000 images for class Space
# Saved 520/2000 images for class Space
# Saved 521/2000 images for class Space
# Saved 522/2000 images for class Space
# Saved 523/2000 images for class Space
# Saved 524/2000 images for class Space
# Saved 525/2000 images for class Space
# Saved 526/2000 images for class Space
# Saved 527/2000 images for class Space
# Saved 528/2000 images for class Space
# Saved 529/2000 images for class Space
# Saved 530/2000 images for class Space
# Saved 531/2000 images for class Space
# Saved 532/2000 images for class Space
# Saved 533/2000 images for class Space
# Saved 534/2000 images for class Space
# Saved 535/2000 images for class Space
# Saved 536/2000 images for class Space
# Saved 537/2000 images for class Space
# Saved 538/2000 images for class Space
# Saved 539/2000 images for class Space
# Saved 540/2000 images for class Space
# Saved 541/2000 images for class Space
# Saved 542/2000 images for class Space
# Saved 543/2000 images for class Space
# Saved 544/2000 images for class Space
# Saved 545/2000 images for class Space
# Saved 546/2000 images for class Space
# Saved 547/2000 images for class Space
# Saved 548/2000 images for class Space
# Saved 549/2000 images for class Space
# Saved 550/2000 images for class Space
# Saved 551/2000 images for class Space
# Saved 552/2000 images for class Space
# Saved 553/2000 images for class Space
# Saved 554/2000 images for class Space
# Saved 555/2000 images for class Space
# Saved 556/2000 images for class Space
# Saved 557/2000 images for class Space
# Saved 558/2000 images for class Space
# Saved 559/2000 images for class Space
# Saved 560/2000 images for class Space
# Saved 561/2000 images for class Space
# Saved 562/2000 images for class Space
# Saved 563/2000 images for class Space
# Saved 564/2000 images for class Space
# Saved 565/2000 images for class Space
# Saved 566/2000 images for class Space
# Saved 567/2000 images for class Space
# Saved 568/2000 images for class Space
# Saved 569/2000 images for class Space
# Saved 570/2000 images for class Space
# Saved 571/2000 images for class Space
# Saved 572/2000 images for class Space
# Saved 573/2000 images for class Space
# Saved 574/2000 images for class Space
# Saved 575/2000 images for class Space
# Saved 576/2000 images for class Space
# Saved 577/2000 images for class Space
# Saved 578/2000 images for class Space
# Saved 579/2000 images for class Space
# Saved 580/2000 images for class Space
# Saved 581/2000 images for class Space
# Saved 582/2000 images for class Space
# Saved 583/2000 images for class Space
# Saved 584/2000 images for class Space
# Saved 585/2000 images for class Space
# Saved 586/2000 images for class Space
# Saved 587/2000 images for class Space
# Saved 588/2000 images for class Space
# Saved 589/2000 images for class Space
# Saved 590/2000 images for class Space
# Saved 591/2000 images for class Space
# Saved 592/2000 images for class Space
# Saved 593/2000 images for class Space
# Saved 594/2000 images for class Space
# Saved 595/2000 images for class Space
# Saved 596/2000 images for class Space
# Saved 597/2000 images for class Space
# Saved 598/2000 images for class Space
# Saved 599/2000 images for class Space
# Saved 600/2000 images for class Space
# Saved 601/2000 images for class Space
# Saved 602/2000 images for class Space
# Saved 603/2000 images for class Space
# Saved 604/2000 images for class Space
# Saved 605/2000 images for class Space
# Saved 606/2000 images for class Space
# Saved 607/2000 images for class Space
# Saved 608/2000 images for class Space
# Saved 609/2000 images for class Space
# Saved 610/2000 images for class Space
# Saved 611/2000 images for class Space
# Saved 612/2000 images for class Space
# Saved 613/2000 images for class Space
# Saved 614/2000 images for class Space
# Saved 615/2000 images for class Space
# Saved 616/2000 images for class Space
# Saved 617/2000 images for class Space
# Saved 618/2000 images for class Space
# Saved 619/2000 images for class Space
# Saved 620/2000 images for class Space
# Saved 621/2000 images for class Space
# Saved 622/2000 images for class Space
# Saved 623/2000 images for class Space
# Saved 624/2000 images for class Space
# Saved 625/2000 images for class Space
# Saved 626/2000 images for class Space
# Saved 627/2000 images for class Space
# Saved 628/2000 images for class Space
# Saved 629/2000 images for class Space
# Saved 630/2000 images for class Space
# Saved 631/2000 images for class Space
# Saved 632/2000 images for class Space
# Saved 633/2000 images for class Space
# Saved 634/2000 images for class Space
# Saved 635/2000 images for class Space
# Saved 636/2000 images for class Space
# Saved 637/2000 images for class Space
# Saved 638/2000 images for class Space
# Saved 639/2000 images for class Space
# Saved 640/2000 images for class Space
# Saved 641/2000 images for class Space
# Saved 642/2000 images for class Space
# Saved 643/2000 images for class Space
# Saved 644/2000 images for class Space
# Saved 645/2000 images for class Space
# Saved 646/2000 images for class Space
# Saved 647/2000 images for class Space
# Saved 648/2000 images for class Space
# Saved 649/2000 images for class Space
# Saved 650/2000 images for class Space
# Saved 651/2000 images for class Space
# Saved 652/2000 images for class Space
# Saved 653/2000 images for class Space
# Saved 654/2000 images for class Space
# Saved 655/2000 images for class Space
# Saved 656/2000 images for class Space
# Saved 657/2000 images for class Space
# Saved 658/2000 images for class Space
# Saved 659/2000 images for class Space
# Saved 660/2000 images for class Space
# Saved 661/2000 images for class Space
# Saved 662/2000 images for class Space
# Saved 663/2000 images for class Space
# Saved 664/2000 images for class Space
# Saved 665/2000 images for class Space
# Saved 666/2000 images for class Space
# Saved 667/2000 images for class Space
# Saved 668/2000 images for class Space
# Saved 669/2000 images for class Space
# Saved 670/2000 images for class Space
# Saved 671/2000 images for class Space
# Saved 672/2000 images for class Space
# Saved 673/2000 images for class Space
# Saved 674/2000 images for class Space
# Saved 675/2000 images for class Space
# Saved 676/2000 images for class Space
# Saved 677/2000 images for class Space
# Saved 678/2000 images for class Space
# Saved 679/2000 images for class Space
# Saved 680/2000 images for class Space
# Saved 681/2000 images for class Space
# Saved 682/2000 images for class Space
# Saved 683/2000 images for class Space
# Saved 684/2000 images for class Space
# Saved 685/2000 images for class Space
# Saved 686/2000 images for class Space
# Saved 687/2000 images for class Space
# Saved 688/2000 images for class Space
# Saved 689/2000 images for class Space
# Saved 690/2000 images for class Space
# Saved 691/2000 images for class Space
# Saved 692/2000 images for class Space
# Saved 693/2000 images for class Space
# Saved 694/2000 images for class Space
# Saved 695/2000 images for class Space
# Saved 696/2000 images for class Space
# Saved 697/2000 images for class Space
# Saved 698/2000 images for class Space
# Saved 699/2000 images for class Space
# Saved 700/2000 images for class Space
# Saved 701/2000 images for class Space
# Saved 702/2000 images for class Space
# Saved 703/2000 images for class Space
# Saved 704/2000 images for class Space
# Saved 705/2000 images for class Space
# Saved 706/2000 images for class Space
# Saved 707/2000 images for class Space
# Saved 708/2000 images for class Space
# Saved 709/2000 images for class Space
# Saved 710/2000 images for class Space
# Saved 711/2000 images for class Space
# Saved 712/2000 images for class Space
# Saved 713/2000 images for class Space
# Saved 714/2000 images for class Space
# Saved 715/2000 images for class Space
# Saved 716/2000 images for class Space
# Saved 717/2000 images for class Space
# Saved 718/2000 images for class Space
# Saved 719/2000 images for class Space
# Saved 720/2000 images for class Space
# Saved 721/2000 images for class Space
# Saved 722/2000 images for class Space
# Saved 723/2000 images for class Space
# Saved 724/2000 images for class Space
# Saved 725/2000 images for class Space
# Saved 726/2000 images for class Space
# Saved 727/2000 images for class Space
# Saved 728/2000 images for class Space
# Saved 729/2000 images for class Space
# Saved 730/2000 images for class Space
# Saved 731/2000 images for class Space
# Saved 732/2000 images for class Space
# Saved 733/2000 images for class Space
# Saved 734/2000 images for class Space
# Saved 735/2000 images for class Space
# Saved 736/2000 images for class Space
# Saved 737/2000 images for class Space
# Saved 738/2000 images for class Space
# Saved 739/2000 images for class Space
# Saved 740/2000 images for class Space
# Saved 741/2000 images for class Space
# Saved 742/2000 images for class Space
# Saved 743/2000 images for class Space
# Saved 744/2000 images for class Space
# Saved 745/2000 images for class Space
# Saved 746/2000 images for class Space
# Saved 747/2000 images for class Space
# Saved 748/2000 images for class Space
# Saved 749/2000 images for class Space
# Saved 750/2000 images for class Space
# Saved 751/2000 images for class Space
# Saved 752/2000 images for class Space
# Saved 753/2000 images for class Space
# Saved 754/2000 images for class Space
# Saved 755/2000 images for class Space
# Saved 756/2000 images for class Space
# Saved 757/2000 images for class Space
# Saved 758/2000 images for class Space
# Saved 759/2000 images for class Space
# Saved 760/2000 images for class Space
# Saved 761/2000 images for class Space
# Saved 762/2000 images for class Space
# Saved 763/2000 images for class Space
# Saved 764/2000 images for class Space
# Saved 765/2000 images for class Space
# Saved 766/2000 images for class Space
# Saved 767/2000 images for class Space
# Saved 768/2000 images for class Space
# Saved 769/2000 images for class Space
# Saved 770/2000 images for class Space
# Saved 771/2000 images for class Space
# Saved 772/2000 images for class Space
# Saved 773/2000 images for class Space
# Saved 774/2000 images for class Space
# Saved 775/2000 images for class Space
# Saved 776/2000 images for class Space
# Saved 777/2000 images for class Space
# Saved 778/2000 images for class Space
# Saved 779/2000 images for class Space
# Saved 780/2000 images for class Space
# Saved 781/2000 images for class Space
# Saved 782/2000 images for class Space
# Saved 783/2000 images for class Space
# Saved 784/2000 images for class Space
# Saved 785/2000 images for class Space
# Saved 786/2000 images for class Space
# Saved 787/2000 images for class Space
# Saved 788/2000 images for class Space
# Saved 789/2000 images for class Space
# Saved 790/2000 images for class Space
# Saved 791/2000 images for class Space
# Saved 792/2000 images for class Space
# Saved 793/2000 images for class Space
# Saved 794/2000 images for class Space
# Saved 795/2000 images for class Space
# Saved 796/2000 images for class Space
# Saved 797/2000 images for class Space
# Saved 798/2000 images for class Space
# Saved 799/2000 images for class Space
# Saved 800/2000 images for class Space
# Saved 801/2000 images for class Space
# Saved 802/2000 images for class Space
# Saved 803/2000 images for class Space
# Saved 804/2000 images for class Space
# Saved 805/2000 images for class Space
# Saved 806/2000 images for class Space
# Saved 807/2000 images for class Space
# Saved 808/2000 images for class Space
# Saved 809/2000 images for class Space
# Saved 810/2000 images for class Space
# Saved 811/2000 images for class Space
# Saved 812/2000 images for class Space
# Saved 813/2000 images for class Space
# Saved 814/2000 images for class Space
# Saved 815/2000 images for class Space
# Saved 816/2000 images for class Space
# Saved 817/2000 images for class Space
# Saved 818/2000 images for class Space
# Saved 819/2000 images for class Space
# Saved 820/2000 images for class Space
# Saved 821/2000 images for class Space
# Saved 822/2000 images for class Space
# Saved 823/2000 images for class Space
# Saved 824/2000 images for class Space
# Saved 825/2000 images for class Space
# Saved 826/2000 images for class Space
# Saved 827/2000 images for class Space
# Saved 828/2000 images for class Space
# Saved 829/2000 images for class Space
# Saved 830/2000 images for class Space
# Saved 831/2000 images for class Space
# Saved 832/2000 images for class Space
# Saved 833/2000 images for class Space
# Saved 834/2000 images for class Space
# Saved 835/2000 images for class Space
# Saved 836/2000 images for class Space
# Saved 837/2000 images for class Space
# Saved 838/2000 images for class Space
# Saved 839/2000 images for class Space
# Saved 840/2000 images for class Space
# Saved 841/2000 images for class Space
# Saved 842/2000 images for class Space
# Saved 843/2000 images for class Space
# Saved 844/2000 images for class Space
# Saved 845/2000 images for class Space
# Saved 846/2000 images for class Space
# Saved 847/2000 images for class Space
# Saved 848/2000 images for class Space
# Saved 849/2000 images for class Space
# Saved 850/2000 images for class Space
# Saved 851/2000 images for class Space
# Saved 852/2000 images for class Space
# Saved 853/2000 images for class Space
# Saved 854/2000 images for class Space
# Saved 855/2000 images for class Space
# Saved 856/2000 images for class Space
# Saved 857/2000 images for class Space
# Saved 858/2000 images for class Space
# Saved 859/2000 images for class Space
# Saved 860/2000 images for class Space
# Saved 861/2000 images for class Space
# Saved 862/2000 images for class Space
# Saved 863/2000 images for class Space
# Saved 864/2000 images for class Space
# Saved 865/2000 images for class Space
# Saved 866/2000 images for class Space
# Saved 867/2000 images for class Space
# Saved 868/2000 images for class Space
# Saved 869/2000 images for class Space
# Saved 870/2000 images for class Space
# Saved 871/2000 images for class Space
# Saved 872/2000 images for class Space
# Saved 873/2000 images for class Space
# Saved 874/2000 images for class Space
# Saved 875/2000 images for class Space
# Saved 876/2000 images for class Space
# Saved 877/2000 images for class Space
# Saved 878/2000 images for class Space
# Saved 879/2000 images for class Space
# Saved 880/2000 images for class Space
# Saved 881/2000 images for class Space
# Saved 882/2000 images for class Space
# Saved 883/2000 images for class Space
# Saved 884/2000 images for class Space
# Saved 885/2000 images for class Space
# Saved 886/2000 images for class Space
# Saved 887/2000 images for class Space
# Saved 888/2000 images for class Space
# Saved 889/2000 images for class Space
# Saved 890/2000 images for class Space
# Saved 891/2000 images for class Space
# Saved 892/2000 images for class Space
# Saved 893/2000 images for class Space
# Saved 894/2000 images for class Space
# Saved 895/2000 images for class Space
# Saved 896/2000 images for class Space
# Saved 897/2000 images for class Space
# Saved 898/2000 images for class Space
# Saved 899/2000 images for class Space
# Saved 900/2000 images for class Space
# Saved 901/2000 images for class Space
# Saved 902/2000 images for class Space
# Saved 903/2000 images for class Space
# Saved 904/2000 images for class Space
# Saved 905/2000 images for class Space
# Saved 906/2000 images for class Space
# Saved 907/2000 images for class Space
# Saved 908/2000 images for class Space
# Saved 909/2000 images for class Space
# Saved 910/2000 images for class Space
# Saved 911/2000 images for class Space
# Saved 912/2000 images for class Space
# Saved 913/2000 images for class Space
# Saved 914/2000 images for class Space
# Saved 915/2000 images for class Space
# Saved 916/2000 images for class Space
# Saved 917/2000 images for class Space
# Saved 918/2000 images for class Space
# Saved 919/2000 images for class Space
# Saved 920/2000 images for class Space
# Saved 921/2000 images for class Space
# Saved 922/2000 images for class Space
# Saved 923/2000 images for class Space
# Saved 924/2000 images for class Space
# Saved 925/2000 images for class Space
# Saved 926/2000 images for class Space
# Saved 927/2000 images for class Space
# Saved 928/2000 images for class Space
# Saved 929/2000 images for class Space
# Saved 930/2000 images for class Space
# Saved 931/2000 images for class Space
# Saved 932/2000 images for class Space
# Saved 933/2000 images for class Space
# Saved 934/2000 images for class Space
# Saved 935/2000 images for class Space
# Saved 936/2000 images for class Space
# Saved 937/2000 images for class Space
# Saved 938/2000 images for class Space
# Saved 939/2000 images for class Space
# Saved 940/2000 images for class Space
# Saved 941/2000 images for class Space
# Saved 942/2000 images for class Space
# Saved 943/2000 images for class Space
# Saved 944/2000 images for class Space
# Saved 945/2000 images for class Space
# Saved 946/2000 images for class Space
# Saved 947/2000 images for class Space
# Saved 948/2000 images for class Space
# Saved 949/2000 images for class Space
# Saved 950/2000 images for class Space
# Saved 951/2000 images for class Space
# Saved 952/2000 images for class Space
# Saved 953/2000 images for class Space
# Saved 954/2000 images for class Space
# Saved 955/2000 images for class Space
# Saved 956/2000 images for class Space
# Saved 957/2000 images for class Space
# Saved 958/2000 images for class Space
# Saved 959/2000 images for class Space
# Saved 960/2000 images for class Space
# Saved 961/2000 images for class Space
# Saved 962/2000 images for class Space
# Saved 963/2000 images for class Space
# Saved 964/2000 images for class Space
# Saved 965/2000 images for class Space
# Saved 966/2000 images for class Space
# Saved 967/2000 images for class Space
# Saved 968/2000 images for class Space
# Saved 969/2000 images for class Space
# Saved 970/2000 images for class Space
# Saved 971/2000 images for class Space
# Saved 972/2000 images for class Space
# Saved 973/2000 images for class Space
# Saved 974/2000 images for class Space
# Saved 975/2000 images for class Space
# Saved 976/2000 images for class Space
# Saved 977/2000 images for class Space
# Saved 978/2000 images for class Space
# Saved 979/2000 images for class Space
# Saved 980/2000 images for class Space
# Saved 981/2000 images for class Space
# Saved 982/2000 images for class Space
# Saved 983/2000 images for class Space
# Saved 984/2000 images for class Space
# Saved 985/2000 images for class Space
# Saved 986/2000 images for class Space
# Saved 987/2000 images for class Space
# Saved 988/2000 images for class Space
# Saved 989/2000 images for class Space
# Saved 990/2000 images for class Space
# Saved 991/2000 images for class Space
# Saved 992/2000 images for class Space
# Saved 993/2000 images for class Space
# Saved 994/2000 images for class Space
# Saved 995/2000 images for class Space
# Saved 996/2000 images for class Space
# Saved 997/2000 images for class Space
# Saved 998/2000 images for class Space
# Saved 999/2000 images for class Space
# Saved 1000/2000 images for class Space
# Saved 1001/2000 images for class Space
# Saved 1002/2000 images for class Space
# Saved 1003/2000 images for class Space
# Saved 1004/2000 images for class Space
# Saved 1005/2000 images for class Space
# Saved 1006/2000 images for class Space
# Saved 1007/2000 images for class Space
# Saved 1008/2000 images for class Space
# Saved 1009/2000 images for class Space
# Saved 1010/2000 images for class Space
# Saved 1011/2000 images for class Space
# Saved 1012/2000 images for class Space
# Saved 1013/2000 images for class Space
# Saved 1014/2000 images for class Space
# Saved 1015/2000 images for class Space
# Saved 1016/2000 images for class Space
# Saved 1017/2000 images for class Space
# Saved 1018/2000 images for class Space
# Saved 1019/2000 images for class Space
# Saved 1020/2000 images for class Space
# Saved 1021/2000 images for class Space
# Saved 1022/2000 images for class Space
# Saved 1023/2000 images for class Space
# Saved 1024/2000 images for class Space
# Saved 1025/2000 images for class Space
# Saved 1026/2000 images for class Space
# Saved 1027/2000 images for class Space
# Saved 1028/2000 images for class Space
# Saved 1029/2000 images for class Space
# Saved 1030/2000 images for class Space
# Saved 1031/2000 images for class Space
# Saved 1032/2000 images for class Space
# Saved 1033/2000 images for class Space
# Saved 1034/2000 images for class Space
# Saved 1035/2000 images for class Space
# Saved 1036/2000 images for class Space
# Saved 1037/2000 images for class Space
# Saved 1038/2000 images for class Space
# Saved 1039/2000 images for class Space
# Saved 1040/2000 images for class Space
# Saved 1041/2000 images for class Space
# Saved 1042/2000 images for class Space
# Saved 1043/2000 images for class Space
# Saved 1044/2000 images for class Space
# Saved 1045/2000 images for class Space
# Saved 1046/2000 images for class Space
# Saved 1047/2000 images for class Space
# Saved 1048/2000 images for class Space
# Saved 1049/2000 images for class Space
# Saved 1050/2000 images for class Space
# Saved 1051/2000 images for class Space
# Saved 1052/2000 images for class Space
# Saved 1053/2000 images for class Space
# Saved 1054/2000 images for class Space
# Saved 1055/2000 images for class Space
# Saved 1056/2000 images for class Space
# Saved 1057/2000 images for class Space
# Saved 1058/2000 images for class Space
# Saved 1059/2000 images for class Space
# Saved 1060/2000 images for class Space
# Saved 1061/2000 images for class Space
# Saved 1062/2000 images for class Space
# Saved 1063/2000 images for class Space
# Saved 1064/2000 images for class Space
# Saved 1065/2000 images for class Space
# Saved 1066/2000 images for class Space
# Saved 1067/2000 images for class Space
# Saved 1068/2000 images for class Space
# Saved 1069/2000 images for class Space
# Saved 1070/2000 images for class Space
# Saved 1071/2000 images for class Space
# Saved 1072/2000 images for class Space
# Saved 1073/2000 images for class Space
# Saved 1074/2000 images for class Space
# Saved 1075/2000 images for class Space
# Saved 1076/2000 images for class Space
# Saved 1077/2000 images for class Space
# Saved 1078/2000 images for class Space
# Saved 1079/2000 images for class Space
# Saved 1080/2000 images for class Space
# Saved 1081/2000 images for class Space
# Saved 1082/2000 images for class Space
# Saved 1083/2000 images for class Space
# Saved 1084/2000 images for class Space
# Saved 1085/2000 images for class Space
# Saved 1086/2000 images for class Space
# Saved 1087/2000 images for class Space
# Saved 1088/2000 images for class Space
# Saved 1089/2000 images for class Space
# Saved 1090/2000 images for class Space
# Saved 1091/2000 images for class Space
# Saved 1092/2000 images for class Space
# Saved 1093/2000 images for class Space
# Saved 1094/2000 images for class Space
# Saved 1095/2000 images for class Space
# Saved 1096/2000 images for class Space
# Saved 1097/2000 images for class Space
# Saved 1098/2000 images for class Space
# Saved 1099/2000 images for class Space
# Saved 1100/2000 images for class Space
# Saved 1101/2000 images for class Space
# Saved 1102/2000 images for class Space
# Saved 1103/2000 images for class Space
# Saved 1104/2000 images for class Space
# Saved 1105/2000 images for class Space
# Saved 1106/2000 images for class Space
# Saved 1107/2000 images for class Space
# Saved 1108/2000 images for class Space
# Saved 1109/2000 images for class Space
# Saved 1110/2000 images for class Space
# Saved 1111/2000 images for class Space
# Saved 1112/2000 images for class Space
# Saved 1113/2000 images for class Space
# Saved 1114/2000 images for class Space
# Saved 1115/2000 images for class Space
# Saved 1116/2000 images for class Space
# Saved 1117/2000 images for class Space
# Saved 1118/2000 images for class Space
# Saved 1119/2000 images for class Space
# Saved 1120/2000 images for class Space
# Saved 1121/2000 images for class Space
# Saved 1122/2000 images for class Space
# Saved 1123/2000 images for class Space
# Saved 1124/2000 images for class Space
# Saved 1125/2000 images for class Space
# Saved 1126/2000 images for class Space
# Saved 1127/2000 images for class Space
# Saved 1128/2000 images for class Space
# Saved 1129/2000 images for class Space
# Saved 1130/2000 images for class Space
# Saved 1131/2000 images for class Space
# Saved 1132/2000 images for class Space
# Saved 1133/2000 images for class Space
# Saved 1134/2000 images for class Space
# Saved 1135/2000 images for class Space
# Saved 1136/2000 images for class Space
# Saved 1137/2000 images for class Space
# Saved 1138/2000 images for class Space
# Saved 1139/2000 images for class Space
# Saved 1140/2000 images for class Space
# Saved 1141/2000 images for class Space
# Saved 1142/2000 images for class Space
# Saved 1143/2000 images for class Space
# Saved 1144/2000 images for class Space
# Saved 1145/2000 images for class Space
# Saved 1146/2000 images for class Space
# Saved 1147/2000 images for class Space
# Saved 1148/2000 images for class Space
# Saved 1149/2000 images for class Space
# Saved 1150/2000 images for class Space
# Saved 1151/2000 images for class Space
# Saved 1152/2000 images for class Space
# Saved 1153/2000 images for class Space
# Saved 1154/2000 images for class Space
# Saved 1155/2000 images for class Space
# Saved 1156/2000 images for class Space
# Saved 1157/2000 images for class Space
# Saved 1158/2000 images for class Space
# Saved 1159/2000 images for class Space
# Saved 1160/2000 images for class Space
# Saved 1161/2000 images for class Space
# Saved 1162/2000 images for class Space
# Saved 1163/2000 images for class Space
# Saved 1164/2000 images for class Space
# Saved 1165/2000 images for class Space
# Saved 1166/2000 images for class Space
# Saved 1167/2000 images for class Space
# Saved 1168/2000 images for class Space
# Saved 1169/2000 images for class Space
# Saved 1170/2000 images for class Space
# Saved 1171/2000 images for class Space
# Saved 1172/2000 images for class Space
# Saved 1173/2000 images for class Space
# Saved 1174/2000 images for class Space
# Saved 1175/2000 images for class Space
# Saved 1176/2000 images for class Space
# Saved 1177/2000 images for class Space
# Saved 1178/2000 images for class Space
# Saved 1179/2000 images for class Space
# Saved 1180/2000 images for class Space
# Saved 1181/2000 images for class Space
# Saved 1182/2000 images for class Space
# Saved 1183/2000 images for class Space
# Saved 1184/2000 images for class Space
# Saved 1185/2000 images for class Space
# Saved 1186/2000 images for class Space
# Saved 1187/2000 images for class Space
# Saved 1188/2000 images for class Space
# Saved 1189/2000 images for class Space
# Saved 1190/2000 images for class Space
# Saved 1191/2000 images for class Space
# Saved 1192/2000 images for class Space
# Saved 1193/2000 images for class Space
# Saved 1194/2000 images for class Space
# Saved 1195/2000 images for class Space
# Saved 1196/2000 images for class Space
# Saved 1197/2000 images for class Space
# Saved 1198/2000 images for class Space
# Saved 1199/2000 images for class Space
# Saved 1200/2000 images for class Space
# Saved 1201/2000 images for class Space
# Saved 1202/2000 images for class Space
# Saved 1203/2000 images for class Space
# Saved 1204/2000 images for class Space
# Saved 1205/2000 images for class Space
# Saved 1206/2000 images for class Space
# Saved 1207/2000 images for class Space
# Saved 1208/2000 images for class Space
# Saved 1209/2000 images for class Space
# Saved 1210/2000 images for class Space
# Saved 1211/2000 images for class Space
# Saved 1212/2000 images for class Space
# Saved 1213/2000 images for class Space
# Saved 1214/2000 images for class Space
# Saved 1215/2000 images for class Space
# Saved 1216/2000 images for class Space
# Saved 1217/2000 images for class Space
# Saved 1218/2000 images for class Space
# Saved 1219/2000 images for class Space
# Saved 1220/2000 images for class Space
# Saved 1221/2000 images for class Space
# Saved 1222/2000 images for class Space
# Saved 1223/2000 images for class Space
# Saved 1224/2000 images for class Space
# Saved 1225/2000 images for class Space
# Saved 1226/2000 images for class Space
# Saved 1227/2000 images for class Space
# Saved 1228/2000 images for class Space
# Saved 1229/2000 images for class Space
# Saved 1230/2000 images for class Space
# Saved 1231/2000 images for class Space
# Saved 1232/2000 images for class Space
# Saved 1233/2000 images for class Space
# Saved 1234/2000 images for class Space
# Saved 1235/2000 images for class Space
# Saved 1236/2000 images for class Space
# Saved 1237/2000 images for class Space
# Saved 1238/2000 images for class Space
# Saved 1239/2000 images for class Space
# Saved 1240/2000 images for class Space
# Saved 1241/2000 images for class Space
# Saved 1242/2000 images for class Space
# ...
# Saved 1592/2000 images for class Space
# Saved 1593/2000 images for class Space
# Saved 1594/2000 images for class Space
# Saved 1595/2000 images for class Space
# Saved 1596/2000 images for class Space
# Saved 1597/2000 images for class Space
# Saved 1598/2000 images for class Space
# Saved 1599/2000 images for class Space
# Saved 1600/2000 images for class Space
# Saved 1601/2000 images for class Space
# Saved 1602/2000 images for class Space
# Saved 1603/2000 images for class Space
# Saved 1604/2000 images for class Space
# Saved 1605/2000 images for class Space
# Saved 1606/2000 images for class Space
# Saved 1607/2000 images for class Space
# Saved 1608/2000 images for class Space
# Saved 1609/2000 images for class Space
# Saved 1610/2000 images for class Space
# Saved 1611/2000 images for class Space
# Saved 1612/2000 images for class Space
# Saved 1613/2000 images for class Space
# Saved 1614/2000 images for class Space
# Saved 1615/2000 images for class Space
# Saved 1616/2000 images for class Space
# Saved 1617/2000 images for class Space
# Saved 1618/2000 images for class Space
# Saved 1619/2000 images for class Space
# Saved 1620/2000 images for class Space
# Saved 1621/2000 images for class Space
# Saved 1622/2000 images for class Space
# Saved 1623/2000 images for class Space
# Saved 1624/2000 images for class Space
# Saved 1625/2000 images for class Space
# Saved 1626/2000 images for class Space
# Saved 1627/2000 images for class Space
# Saved 1628/2000 images for class Space
# Saved 1629/2000 images for class Space
# Saved 1630/2000 images for class Space
# Saved 1631/2000 images for class Space
# Saved 1632/2000 images for class Space
# Saved 1633/2000 images for class Space
# Saved 1634/2000 images for class Space
# Saved 1635/2000 images for class Space
# Saved 1636/2000 images for class Space
# Saved 1637/2000 images for class Space
# Saved 1638/2000 images for class Space
# Saved 1639/2000 images for class Space
# Saved 1640/2000 images for class Space
# Saved 1641/2000 images for class Space
# Saved 1642/2000 images for class Space
# Saved 1643/2000 images for class Space
# Saved 1644/2000 images for class Space
# Saved 1645/2000 images for class Space
# Saved 1646/2000 images for class Space
# Saved 1647/2000 images for class Space
# Saved 1648/2000 images for class Space
# Saved 1649/2000 images for class Space
# Saved 1650/2000 images for class Space
# Saved 1651/2000 images for class Space
# Saved 1652/2000 images for class Space
# Saved 1653/2000 images for class Space
# Saved 1654/2000 images for class Space
# Saved 1655/2000 images for class Space
# Saved 1656/2000 images for class Space
# Saved 1657/2000 images for class Space
# Saved 1658/2000 images for class Space
# Saved 1659/2000 images for class Space
# Saved 1660/2000 images for class Space
# Saved 1661/2000 images for class Space
# Saved 1662/2000 images for class Space
# Saved 1663/2000 images for class Space
# Saved 1664/2000 images for class Space
# Saved 1665/2000 images for class Space
# Saved 1666/2000 images for class Space
# Saved 1667/2000 images for class Space
# Saved 1668/2000 images for class Space
# Saved 1669/2000 images for class Space
# Saved 1670/2000 images for class Space
# Saved 1671/2000 images for class Space
# Saved 1672/2000 images for class Space
# Saved 1673/2000 images for class Space
# Saved 1674/2000 images for class Space
# Saved 1675/2000 images for class Space
# Saved 1676/2000 images for class Space
# Saved 1677/2000 images for class Space
# Saved 1678/2000 images for class Space
# Saved 1679/2000 images for class Space
# Saved 1680/2000 images for class Space
# Saved 1681/2000 images for class Space
# Saved 1682/2000 images for class Space
# Saved 1683/2000 images for class Space
# Saved 1684/2000 images for class Space
# Saved 1685/2000 images for class Space
# Saved 1686/2000 images for class Space
# Saved 1687/2000 images for class Space
# Saved 1688/2000 images for class Space
# Saved 1689/2000 images for class Space
# Saved 1690/2000 images for class Space
# Saved 1691/2000 images for class Space
# Saved 1692/2000 images for class Space
# Saved 1693/2000 images for class Space
# Saved 1694/2000 images for class Space
# Saved 1695/2000 images for class Space
# Saved 1696/2000 images for class Space
# Saved 1697/2000 images for class Space
# Saved 1698/2000 images for class Space
# Saved 1699/2000 images for class Space
# Saved 1700/2000 images for class Space
# Saved 1701/2000 images for class Space
# Saved 1702/2000 images for class Space
# Saved 1703/2000 images for class Space
# Saved 1704/2000 images for class Space
# Saved 1705/2000 images for class Space
# Saved 1706/2000 images for class Space
# Saved 1707/2000 images for class Space
# Saved 1708/2000 images for class Space
# Saved 1709/2000 images for class Space
# Saved 1710/2000 images for class Space
# Saved 1711/2000 images for class Space
# Saved 1712/2000 images for class Space
# Saved 1713/2000 images for class Space
# Saved 1714/2000 images for class Space
# Saved 1715/2000 images for class Space
# Saved 1716/2000 images for class Space
# Saved 1717/2000 images for class Space
# Saved 1718/2000 images for class Space
# Saved 1719/2000 images for class Space
# Saved 1720/2000 images for class Space
# Saved 1721/2000 images for class Space
# Saved 1722/2000 images for class Space
# Saved 1723/2000 images for class Space
# Saved 1724/2000 images for class Space
# Saved 1725/2000 images for class Space
# Saved 1726/2000 images for class Space
# Saved 1727/2000 images for class Space
# Saved 1728/2000 images for class Space
# Saved 1729/2000 images for class Space
# Saved 1730/2000 images for class Space
# Saved 1731/2000 images for class Space
# Saved 1732/2000 images for class Space
# Saved 1733/2000 images for class Space
# Saved 1734/2000 images for class Space
# Saved 1735/2000 images for class Space
# Saved 1736/2000 images for class Space
# Saved 1737/2000 images for class Space
# Saved 1738/2000 images for class Space
# Saved 1739/2000 images for class Space
# Saved 1740/2000 images for class Space
# Saved 1741/2000 images for class Space
# Saved 1742/2000 images for class Space
# Saved 1743/2000 images for class Space
# Saved 1744/2000 images for class Space
# Saved 1745/2000 images for class Space
# Saved 1746/2000 images for class Space
# Saved 1747/2000 images for class Space
# Saved 1748/2000 images for class Space
# Saved 1749/2000 images for class Space
# Saved 1750/2000 images for class Space
# Saved 1751/2000 images for class Space
# Saved 1752/2000 images for class Space
# Saved 1753/2000 images for class Space
# Saved 1754/2000 images for class Space
# Saved 1755/2000 images for class Space
# Saved 1756/2000 images for class Space
# Saved 1757/2000 images for class Space
# Saved 1758/2000 images for class Space
# Saved 1759/2000 images for class Space
# Saved 1760/2000 images for class Space
# Saved 1761/2000 images for class Space
# Saved 1762/2000 images for class Space
# Saved 1763/2000 images for class Space
# Saved 1764/2000 images for class Space
# Saved 1765/2000 images for class Space
# Saved 1766/2000 images for class Space
# Saved 1767/2000 images for class Space
# Saved 1768/2000 images for class Space
# Saved 1769/2000 images for class Space
# Saved 1770/2000 images for class Space
# Saved 1771/2000 images for class Space
# Saved 1772/2000 images for class Space
# Saved 1773/2000 images for class Space
# Saved 1774/2000 images for class Space
# Saved 1775/2000 images for class Space
# Saved 1776/2000 images for class Space
# Saved 1777/2000 images for class Space
# Saved 1778/2000 images for class Space
# Saved 1779/2000 images for class Space
# Saved 1780/2000 images for class Space
# Saved 1781/2000 images for class Space
# Saved 1782/2000 images for class Space
# Saved 1783/2000 images for class Space
# Saved 1784/2000 images for class Space
# Saved 1785/2000 images for class Space
# Saved 1786/2000 images for class Space
# Saved 1787/2000 images for class Space
# Saved 1788/2000 images for class Space
# Saved 1789/2000 images for class Space
# Saved 1790/2000 images for class Space
# Saved 1791/2000 images for class Space
# Saved 1792/2000 images for class Space
# Saved 1793/2000 images for class Space
# Saved 1794/2000 images for class Space
# Saved 1795/2000 images for class Space
# Saved 1796/2000 images for class Space
# Saved 1797/2000 images for class Space
# Saved 1798/2000 images for class Space
# Saved 1799/2000 images for class Space
# Saved 1800/2000 images for class Space
# Saved 1801/2000 images for class Space
# Saved 1802/2000 images for class Space
# Saved 1803/2000 images for class Space
# Saved 1804/2000 images for class Space
# Saved 1805/2000 images for class Space
# Saved 1806/2000 images for class Space
# Saved 1807/2000 images for class Space
# Saved 1808/2000 images for class Space
# Saved 1809/2000 images for class Space
# Saved 1810/2000 images for class Space
# Saved 1811/2000 images for class Space
# Saved 1812/2000 images for class Space
# Saved 1813/2000 images for class Space
# Saved 1814/2000 images for class Space
# Saved 1815/2000 images for class Space
# Saved 1816/2000 images for class Space
# Saved 1817/2000 images for class Space
# Saved 1818/2000 images for class Space
# Saved 1819/2000 images for class Space
# Saved 1820/2000 images for class Space
# Saved 1821/2000 images for class Space
# Saved 1822/2000 images for class Space
# Saved 1823/2000 images for class Space
# Saved 1824/2000 images for class Space
# Saved 1825/2000 images for class Space
# Saved 1826/2000 images for class Space
# Saved 1827/2000 images for class Space
# Saved 1828/2000 images for class Space
# Saved 1829/2000 images for class Space
# Saved 1830/2000 images for class Space
# Saved 1831/2000 images for class Space
# Saved 1832/2000 images for class Space
# Saved 1833/2000 images for class Space
# Saved 1834/2000 images for class Space
# Saved 1835/2000 images for class Space
# Saved 1836/2000 images for class Space
# Saved 1837/2000 images for class Space
# Saved 1838/2000 images for class Space
# Saved 1839/2000 images for class Space
# Saved 1840/2000 images for class Space
# Saved 1841/2000 images for class Space
# Saved 1842/2000 images for class Space
# Saved 1843/2000 images for class Space
# Saved 1844/2000 images for class Space
# Saved 1845/2000 images for class Space
# Saved 1846/2000 images for class Space
# Saved 1847/2000 images for class Space
# Saved 1848/2000 images for class Space
# Saved 1849/2000 images for class Space
# Saved 1850/2000 images for class Space
# Saved 1851/2000 images for class Space
# Saved 1852/2000 images for class Space
# Saved 1853/2000 images for class Space
# Saved 1854/2000 images for class Space
# Saved 1855/2000 images for class Space
# Saved 1856/2000 images for class Space
# Saved 1857/2000 images for class Space
# Saved 1858/2000 images for class Space
# Saved 1859/2000 images for class Space
# Saved 1860/2000 images for class Space
# Saved 1861/2000 images for class Space
# Saved 1862/2000 images for class Space
# Saved 1863/2000 images for class Space
# Saved 1864/2000 images for class Space
# Saved 1865/2000 images for class Space
# Saved 1866/2000 images for class Space
# Saved 1867/2000 images for class Space
# Saved 1868/2000 images for class Space
# Saved 1869/2000 images for class Space
# Saved 1870/2000 images for class Space
# Saved 1871/2000 images for class Space
# Saved 1872/2000 images for class Space
# Saved 1873/2000 images for class Space
# Saved 1874/2000 images for class Space
# Saved 1875/2000 images for class Space
# Saved 1876/2000 images for class Space
# Saved 1877/2000 images for class Space
# Saved 1878/2000 images for class Space
# Saved 1879/2000 images for class Space
# Saved 1880/2000 images for class Space
# Saved 1881/2000 images for class Space
# Saved 1882/2000 images for class Space
# Saved 1883/2000 images for class Space
# Saved 1884/2000 images for class Space
# Saved 1885/2000 images for class Space
# Saved 1886/2000 images for class Space
# Saved 1887/2000 images for class Space
# Saved 1888/2000 images for class Space
# Saved 1889/2000 images for class Space
# Saved 1890/2000 images for class Space
# Saved 1891/2000 images for class Space
# Saved 1892/2000 images for class Space
# Saved 1893/2000 images for class Space
# Saved 1894/2000 images for class Space
# Saved 1895/2000 images for class Space
# Saved 1896/2000 images for class Space
# Saved 1897/2000 images for class Space
# Saved 1898/2000 images for class Space
# Saved 1899/2000 images for class Space
# Saved 1900/2000 images for class Space
# Saved 1901/2000 images for class Space
# Saved 1902/2000 images for class Space
# Saved 1903/2000 images for class Space
# Saved 1904/2000 images for class Space
# Saved 1905/2000 images for class Space
# Saved 1906/2000 images for class Space
# Saved 1907/2000 images for class Space
# Saved 1908/2000 images for class Space
# Saved 1909/2000 images for class Space
# Saved 1910/2000 images for class Space
# Saved 1911/2000 images for class Space
# Saved 1912/2000 images for class Space
# Saved 1913/2000 images for class Space
# Saved 1914/2000 images for class Space
# Saved 1915/2000 images for class Space
# Saved 1916/2000 images for class Space
# Saved 1917/2000 images for class Space
# Saved 1918/2000 images for class Space
# Saved 1919/2000 images for class Space
# Saved 1920/2000 images for class Space
# Saved 1921/2000 images for class Space
# Saved 1922/2000 images for class Space
# Saved 1923/2000 images for class Space
# Saved 1924/2000 images for class Space
# Saved 1925/2000 images for class Space
# Saved 1926/2000 images for class Space
# Saved 1927/2000 images for class Space
# Saved 1928/2000 images for class Space
# Saved 1929/2000 images for class Space
# Saved 1930/2000 images for class Space
# Saved 1931/2000 images for class Space
# Saved 1932/2000 images for class Space
# Saved 1933/2000 images for class Space
# Saved 1934/2000 images for class Space
# Saved 1935/2000 images for class Space
# Saved 1936/2000 images for class Space
# Saved 1937/2000 images for class Space
# Saved 1938/2000 images for class Space
# Saved 1939/2000 images for class Space
# Saved 1940/2000 images for class Space
# Saved 1941/2000 images for class Space
# Saved 1942/2000 images for class Space
# Saved 1943/2000 images for class Space
# Saved 1944/2000 images for class Space
# Saved 1945/2000 images for class Space
# Saved 1946/2000 images for class Space
# Saved 1947/2000 images for class Space
# Saved 1948/2000 images for class Space
# Saved 1949/2000 images for class Space
# Saved 1950/2000 images for class Space
# Saved 1951/2000 images for class Space
# Saved 1952/2000 images for class Space
# Saved 1953/2000 images for class Space
# Saved 1954/2000 images for class Space
# Saved 1955/2000 images for class Space
# Saved 1956/2000 images for class Space
# Saved 1957/2000 images for class Space
# Saved 1958/2000 images for class Space
# Saved 1959/2000 images for class Space
# Saved 1960/2000 images for class Space
# Saved 1961/2000 images for class Space
# Saved 1962/2000 images for class Space
# Saved 1963/2000 images for class Space
# Saved 1964/2000 images for class Space
# Saved 1965/2000 images for class Space
# Saved 1966/2000 images for class Space
# Saved 1967/2000 images for class Space
# Saved 1968/2000 images for class Space
# Saved 1969/2000 images for class Space
# Saved 1970/2000 images for class Space
# Saved 1971/2000 images for class Space
# Saved 1972/2000 images for class Space
# Saved 1973/2000 images for class Space
# Saved 1974/2000 images for class Space
# Saved 1975/2000 images for class Space
# Saved 1976/2000 images for class Space
# Saved 1977/2000 images for class Space
# Saved 1978/2000 images for class Space
# Saved 1979/2000 images for class Space
# Saved 1980/2000 images for class Space
# Saved 1981/2000 images for class Space
# Saved 1982/2000 images for class Space
# Saved 1983/2000 images for class Space
# Saved 1984/2000 images for class Space
# Saved 1985/2000 images for class Space
# Saved 1986/2000 images for class Space
# Saved 1987/2000 images for class Space
# Saved 1988/2000 images for class Space
# Saved 1989/2000 images for class Space
# Saved 1990/2000 images for class Space
# Saved 1991/2000 images for class Space
# Saved 1992/2000 images for class Space
# Saved 1993/2000 images for class Space
# Saved 1994/2000 images for class Space
# Saved 1995/2000 images for class Space
# Saved 1996/2000 images for class Space
# Saved 1997/2000 images for class Space
# Saved 1998/2000 images for class Space
# Saved 1999/2000 images for class Space
# Saved 2000/2000 images for class Space
# Completed collection for Space.

# %%
# import cv2
# from cvzone.HandTrackingModule import HandDetector
# import numpy as np
# import math
# import os

# # Initialize webcam
# cap = cv2.VideoCapture(0)

# # Initialize hand detector
# detector = HandDetector(maxHands=1)

# # Constants
# imgSize = 900
# baseFolder = "C:/Users/User/OneDrive/Documents/SignLanguageApp/SLangDataset/data"
# letters = [chr(i) for i in range(ord('A'), ord('Z') + 1)]  # List of letters A-Z
# captureInterval = 0.001  # Interval between captures in seconds
# maxImages = 2000  # Total images to capture per class
# paddingFactor = 0.4  # Padding as a percentage of the hand's size (20%)

# # Function to process and resize images
# def process_and_resize(imgCrop, aspectRatio, imgSize):
#     imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 255
#     try:
#         if aspectRatio > 1:
#             # Height > Width
#             k = imgSize / imgCrop.shape[0]
#             wCal = math.ceil(k * imgCrop.shape[1])
#             imgResize = cv2.resize(imgCrop, (wCal, imgSize))
#             wGap = math.ceil((imgSize - wCal) / 2)
#             imgWhite[:, wGap:wCal + wGap] = imgResize
#         else:
#             # Width > Height
#             k = imgSize / imgCrop.shape[1]
#             hCal = math.ceil(k * imgCrop.shape[0])
#             imgResize = cv2.resize(imgCrop, (imgSize, hCal))
#             hGap = math.ceil((imgSize - hCal) / 2)
#             imgWhite[hGap:hCal + hGap, :] = imgResize
#     except Exception as e:
#         print(f"Error during image processing: {e}")
#         return None
#     return imgWhite

# # Loop through each letter
# for className in letters:
#     print(f"Starting collection for: {className}")
#     folder = os.path.join(baseFolder, className)
#     os.makedirs(folder, exist_ok=True)
    
#     counter, collecting = 0, False
    
#     while counter < maxImages:
#         success, img = cap.read()
#         if not success:
#             print("Camera access failed.")
#             break

#         hands, img = detector.findHands(img)
#         if hands:
#             x, y, w, h = hands[0]['bbox']
            
#             # Dynamically calculate padding based on the hand's size
#             xPad = int(w * paddingFactor)
#             yPad = int(h * paddingFactor)

#             # Crop the image with dynamic padding
#             imgCrop = img[max(0, y - yPad):min(y + h + yPad, img.shape[0]),
#                           max(0, x - xPad):min(x + w + xPad, img.shape[1])]
            
#             if imgCrop.size > 0:
#                 aspectRatio = h / w
#                 imgWhite = process_and_resize(imgCrop, aspectRatio, imgSize)
#                 if imgWhite is not None:
#                     cv2.imshow("Processed", imgWhite)
#                     if collecting:
#                         counter += 1
#                         cv2.imwrite(os.path.join(folder, f"{className.lower()}_{counter}.jpg"), imgWhite)
#                         print(f"Saved {counter}/{maxImages} images for {className}")
            
#             # Draw the bounding box with dynamic padding for visualization
#             cv2.rectangle(img, (x - xPad, y - yPad), (x + w + xPad, y + h + yPad), (0, 255, 0), 2)

#         # Display the original image with the bounding box
#         cv2.imshow("Live Feed", img)
#         key = cv2.waitKey(1)
#         if key == ord('s'): collecting = True
#         if key == ord('p'): collecting = False
#         if key == ord('q'): break

#     print(f"Completed collection for {className}")
#     ask = input("Press Enter for next class.")
#     if ask == 'q': cv2.destroyAllWindows(); break
    


# # Release the webcam and close all windows
# cap.release()
# cv2.destroyAllWindows()


import cv2
from cvzone.HandTrackingModule import HandDetector
import numpy as np
import math
import os

# Initialize webcam
cap = cv2.VideoCapture(0)

# Initialize hand detector
detector = HandDetector(maxHands=1)

# Constants
imgSize = 900
baseFolder = "C:/Users/User/OneDrive/Documents/SignLanguageApp/SLangDataset/data_est"
letters = [chr(i) for i in range(ord('A'), ord('Z') + 1)]  # List of letters A-Z
captureInterval = 0.001  # Interval between captures in seconds
maxImages = 2000  # Total images to capture per class
paddingFactor = 0.5  # Padding as a percentage of the hand's size (20%)

# Function to process and resize images
def process_and_resize(imgCrop, aspectRatio, imgSize):
    imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 0
    try:
        if aspectRatio > 1:
            # Height > Width
            k = imgSize / imgCrop.shape[0]
            wCal = math.ceil(k * imgCrop.shape[1])
            imgResize = cv2.resize(imgCrop, (wCal, imgSize))
            wGap = math.ceil((imgSize - wCal) / 2)
            imgWhite[:, wGap:wCal + wGap] = imgResize
        else:
            # Width > Height
            k = imgSize / imgCrop.shape[1]
            hCal = math.ceil(k * imgCrop.shape[0])
            imgResize = cv2.resize(imgCrop, (imgSize, hCal))
            hGap = math.ceil((imgSize - hCal) / 2)
            imgWhite[hGap:hCal + hGap, :] = imgResize
    except Exception as e:
        print(f"Error during image processing: {e}")
        return None
    return imgWhite

# Loop through each letter
for className in letters:
    print(f"Starting collection for: {className}")
    folder = os.path.join(baseFolder, className)
    os.makedirs(folder, exist_ok=True)
    
    counter, collecting = 0, False
    
    while counter < maxImages:
        success, img = cap.read()
        if not success:
            print("Camera access failed.")
            break

        hands, img = detector.findHands(img, draw=False)
        if hands:
            x, y, w, h = hands[0]['bbox']
            
            # Dynamically calculate padding based on the hand's size
            xPad = int(w * paddingFactor)
            yPad = int(h * paddingFactor)

            # Crop the image with dynamic padding
            imgCrop = img[max(0, y - yPad):min(y + h + yPad, img.shape[0]),
                          max(0, x - xPad):min(x + w + xPad, img.shape[1])]
            
            if imgCrop.size > 0:
                aspectRatio = h / w
                imgWhite = process_and_resize(imgCrop, aspectRatio, imgSize)
                if imgWhite is not None:
                    cv2.imshow("Processed", imgWhite)
                    if collecting:
                        counter += 1
                        cv2.imwrite(os.path.join(folder, f"{className.lower()}_{counter}.jpg"), imgWhite)
                        print(f"Saved {counter}/{maxImages} images for {className}")

        # Display the original image without the bounding box
        cv2.imshow("Live Feed", img)
        key = cv2.waitKey(1)
        if key == ord('s'): collecting = True
        if key == ord('p'): collecting = False
        if key == ord('q'): break

    print(f"Completed collection for {className}")
    input("Press Enter for next class.")

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Starting collection for: A
# Error during image processing: could not broadcast input array from shape (900,1066,3) into shape (900,83,3)
# Error during image processing: could not broadcast input array from shape (901,900,3) into shape (900,900,3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 158
#     155     print("Camera access failed.")
#     156     break
# --> 158 hands, img = detector.findHands(img, draw=False)
#     159 if hands:
#     160     x, y, w, h = hands[0]['bbox']
#
# File c:\Users\User\anaconda3\envs\tensorflow_env\lib\site-packages\cvzone\HandTrackingModule.py:55, in HandDetector.findHands(self, img, draw, flipType)
#      48 """
#      49 Finds hands in a BGR image.
#      50 :param img: Image to find the hands in.
#      51 :param draw: Flag to draw the output on the image.
#      52 :return: Image with or without drawings
#      53 """
#      54 imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# ---> 55 self.results = self.hands.process(imgRGB)
#      56 allHands = []
#      57 h, w, c = img.shape
#
# File ~\AppData\Roaming\Python\Python38\site-packages\mediapipe\python\solutions\hands.py:153, in Hands.process(self, image)
#     132 def process(self, image: np.ndarray) -> NamedTuple:
#     133   """Processes an RGB image and returns the hand landmarks and handedness of each detected hand.
#     134
#     135   Args:
#    (...)
#     150          right hand) of the detected hand.
#     151   """
# --> 153   return super().process(input_data={'image': image})
#
# File ~\AppData\Roaming\Python\Python38\site-packages\mediapipe\python\solution_base.py:335, in SolutionBase.process(self, input_data)
#     329   else:
#     330     self._graph.add_packet_to_input_stream(
#     331         stream=stream_name,
#     332         packet=self._make_packet(input_stream_type,
#     333                                  data).at(self._simulated_timestamp))
# --> 335 self._graph.wait_until_idle()
#     336 # Create a NamedTuple object where the field names are mapping to the graph
#     337 # output stream names.
#     338 solution_outputs = collections.namedtuple(
#     339     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
